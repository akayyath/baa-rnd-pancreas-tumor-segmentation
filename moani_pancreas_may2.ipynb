# %%
import os
import shutil
import tempfile
import time
import matplotlib.pyplot as plt
from monai.apps import DecathlonDataset
from monai.config import print_config
from monai.data import DataLoader, decollate_batch
from monai.handlers.utils import from_engine
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import SegResNet
from monai.transforms import (
    Activations,
    Activationsd,
    AsDiscrete,
    AsDiscreted,
    Compose,
    Invertd,
    LoadImaged,
    MapTransform,
    NormalizeIntensityd,
    Orientationd,
    RandFlipd,
    RandScaleIntensityd,
    RandShiftIntensityd,
    RandSpatialCropd,
    Spacingd,
    EnsureTyped,
    EnsureChannelFirstd,
    SpatialPadd,
    SpatialCropd,
    ScaleIntensityd,
    ShiftIntensityd,
    ResizeD
)
from monai.utils import set_determinism

import torch
import nibabel as nib
print_config()
# Out:
# MONAI version: 1.1.0
# Numpy version: 1.23.5
# Pytorch version: 2.0.1+cu117
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: a2ec3752f54bfc3b40e7952234fbeb5452ed63e3
# MONAI __file__: /usr/local/lib/python3.8/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.12
# Nibabel version: 5.1.0
# scikit-image version: 0.20.0
# Pillow version: 9.5.0
# Tensorboard version: 2.12.3
# gdown version: 4.7.1
# TorchVision version: NOT INSTALLED or UNKNOWN VERSION.
# tqdm version: 4.65.0
# lmdb version: 1.4.1
# psutil version: 5.9.5
# pandas version: 2.0.1
# einops version: 0.6.1
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: 2.3.2
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
data_dir =  "/home/Task07_Pancreas/"
images_dir = os.path.join(data_dir, "imagesTr")
labels_dir = os.path.join(data_dir, "labelsTr")

# %%
image_paths = [os.path.join(images_dir, file) for file in os.listdir(images_dir) if not file.endswith('.DS_Store')]

label_paths = [os.path.join(labels_dir, file) for file in os.listdir(labels_dir) if not file.endswith('.DS_Store')]

# %%
# for image_path, label_path in zip(image_paths, label_paths):
#     # Load image and label using nibabel
#     image = nib.load(image_path).get_fdata()
#     label = nib.load(label_path).get_fdata()

#     # Get number of channels for image (assumed to be the last dimension)
#     num_channels_image = image.shape[-1]

#     # Get number of channels for label (assumed to be the last dimension)
#     num_channels_label = label.shape[-1]

#     # Get number of labels for image
#     num_labels = label.max()

#     print(f"Image '{os.path.basename(image_path)}' has {num_channels_image} image channels.")
#     print(f"Label '{os.path.basename(label_path)}' has {num_channels_label} label channels.")
#     print(f"Image '{os.path.basename(image_path)}' has {num_labels} labels.")
# Out:
# Image 'pancreas_182.nii.gz' has 79 image channels.
# Label 'pancreas_182.nii.gz' has 79 label channels.
# Image 'pancreas_182.nii.gz' has 2.0 labels.
# Image 'pancreas_087.nii.gz' has 77 image channels.
# Label 'pancreas_087.nii.gz' has 77 label channels.
# Image 'pancreas_087.nii.gz' has 2.0 labels.
# Image 'pancreas_001.nii.gz' has 110 image channels.
# Label 'pancreas_001.nii.gz' has 110 label channels.
# Image 'pancreas_001.nii.gz' has 2.0 labels.
# Image 'pancreas_088.nii.gz' has 103 image channels.
# Label 'pancreas_088.nii.gz' has 103 label channels.
# Image 'pancreas_088.nii.gz' has 2.0 labels.
# Image 'pancreas_004.nii.gz' has 107 image channels.
# Label 'pancreas_004.nii.gz' has 107 label channels.
# Image 'pancreas_004.nii.gz' has 2.0 labels.
# Image 'pancreas_089.nii.gz' has 91 image channels.
# Label 'pancreas_089.nii.gz' has 91 label channels.
# Image 'pancreas_089.nii.gz' has 2.0 labels.
# Image 'pancreas_005.nii.gz' has 104 image channels.
# Label 'pancreas_005.nii.gz' has 104 label channels.
# Image 'pancreas_005.nii.gz' has 2.0 labels.
# Image 'pancreas_092.nii.gz' has 92 image channels.
# Label 'pancreas_092.nii.gz' has 92 label channels.
# Image 'pancreas_092.nii.gz' has 2.0 labels.
# Image 'pancreas_006.nii.gz' has 101 image channels.
# Label 'pancreas_006.nii.gz' has 101 label channels.
# Image 'pancreas_006.nii.gz' has 2.0 labels.
# Image 'pancreas_091.nii.gz' has 71 image channels.
# Label 'pancreas_091.nii.gz' has 71 label channels.
# Image 'pancreas_091.nii.gz' has 2.0 labels.
# Image 'pancreas_010.nii.gz' has 174 image channels.
# Label 'pancreas_010.nii.gz' has 174 label channels.
# Image 'pancreas_010.nii.gz' has 2.0 labels.
# Image 'pancreas_093.nii.gz' has 97 image channels.
# Label 'pancreas_093.nii.gz' has 97 label channels.
# Image 'pancreas_093.nii.gz' has 2.0 labels.
# Image 'pancreas_012.nii.gz' has 97 image channels.
# Label 'pancreas_012.nii.gz' has 97 label channels.
# Image 'pancreas_012.nii.gz' has 2.0 labels.
# Image 'pancreas_094.nii.gz' has 84 image channels.
# Label 'pancreas_094.nii.gz' has 84 label channels.
# Image 'pancreas_094.nii.gz' has 2.0 labels.
# Image 'pancreas_015.nii.gz' has 87 image channels.
# Label 'pancreas_015.nii.gz' has 87 label channels.
# Image 'pancreas_015.nii.gz' has 2.0 labels.
# Image 'pancreas_095.nii.gz' has 93 image channels.
# Label 'pancreas_095.nii.gz' has 93 label channels.
# Image 'pancreas_095.nii.gz' has 2.0 labels.
# Image 'pancreas_016.nii.gz' has 85 image channels.
# Label 'pancreas_016.nii.gz' has 85 label channels.
# Image 'pancreas_016.nii.gz' has 2.0 labels.
# Image 'pancreas_105.nii.gz' has 98 image channels.
# Label 'pancreas_105.nii.gz' has 98 label channels.
# Image 'pancreas_105.nii.gz' has 2.0 labels.
# Image 'pancreas_018.nii.gz' has 87 image channels.
# Label 'pancreas_018.nii.gz' has 87 label channels.
# Image 'pancreas_018.nii.gz' has 2.0 labels.
# Image 'pancreas_104.nii.gz' has 100 image channels.
# Label 'pancreas_104.nii.gz' has 100 label channels.
# Image 'pancreas_104.nii.gz' has 2.0 labels.
# Image 'pancreas_019.nii.gz' has 85 image channels.
# Label 'pancreas_019.nii.gz' has 85 label channels.
# Image 'pancreas_019.nii.gz' has 2.0 labels.
# Image 'pancreas_106.nii.gz' has 55 image channels.
# Label 'pancreas_106.nii.gz' has 55 label channels.
# Image 'pancreas_106.nii.gz' has 2.0 labels.
# Image 'pancreas_021.nii.gz' has 93 image channels.
# Label 'pancreas_021.nii.gz' has 93 label channels.
# Image 'pancreas_021.nii.gz' has 2.0 labels.
# Image 'pancreas_107.nii.gz' has 102 image channels.
# Label 'pancreas_107.nii.gz' has 102 label channels.
# Image 'pancreas_107.nii.gz' has 2.0 labels.
# Image 'pancreas_024.nii.gz' has 105 image channels.
# Label 'pancreas_024.nii.gz' has 105 label channels.
# Image 'pancreas_024.nii.gz' has 2.0 labels.
# Image 'pancreas_109.nii.gz' has 99 image channels.
# Label 'pancreas_109.nii.gz' has 99 label channels.
# Image 'pancreas_109.nii.gz' has 2.0 labels.
# Image 'pancreas_025.nii.gz' has 75 image channels.
# Label 'pancreas_025.nii.gz' has 75 label channels.
# Image 'pancreas_025.nii.gz' has 2.0 labels.
# Image 'pancreas_110.nii.gz' has 98 image channels.
# Label 'pancreas_110.nii.gz' has 98 label channels.
# Image 'pancreas_110.nii.gz' has 2.0 labels.
# Image 'pancreas_028.nii.gz' has 83 image channels.
# Label 'pancreas_028.nii.gz' has 83 label channels.
# Image 'pancreas_028.nii.gz' has 2.0 labels.
# Image 'pancreas_111.nii.gz' has 57 image channels.
# Label 'pancreas_111.nii.gz' has 57 label channels.
# Image 'pancreas_111.nii.gz' has 2.0 labels.
# Image 'pancreas_029.nii.gz' has 99 image channels.
# Label 'pancreas_029.nii.gz' has 99 label channels.
# Image 'pancreas_029.nii.gz' has 2.0 labels.
# Image 'pancreas_113.nii.gz' has 100 image channels.
# Label 'pancreas_113.nii.gz' has 100 label channels.
# Image 'pancreas_113.nii.gz' has 2.0 labels.
# Image 'pancreas_032.nii.gz' has 89 image channels.
# Label 'pancreas_032.nii.gz' has 89 label channels.
# Image 'pancreas_032.nii.gz' has 2.0 labels.
# Image 'pancreas_114.nii.gz' has 98 image channels.
# Label 'pancreas_114.nii.gz' has 98 label channels.
# Image 'pancreas_114.nii.gz' has 2.0 labels.
# Image 'pancreas_035.nii.gz' has 73 image channels.
# Label 'pancreas_035.nii.gz' has 73 label channels.
# Image 'pancreas_035.nii.gz' has 2.0 labels.
# Image 'pancreas_117.nii.gz' has 134 image channels.
# Label 'pancreas_117.nii.gz' has 134 label channels.
# Image 'pancreas_117.nii.gz' has 2.0 labels.
# Image 'pancreas_037.nii.gz' has 71 image channels.
# Label 'pancreas_037.nii.gz' has 71 label channels.
# Image 'pancreas_037.nii.gz' has 2.0 labels.
# Image 'pancreas_119.nii.gz' has 85 image channels.
# Label 'pancreas_119.nii.gz' has 85 label channels.
# Image 'pancreas_119.nii.gz' has 2.0 labels.
# Image 'pancreas_040.nii.gz' has 45 image channels.
# Label 'pancreas_040.nii.gz' has 45 label channels.
# Image 'pancreas_040.nii.gz' has 2.0 labels.
# Image 'pancreas_120.nii.gz' has 104 image channels.
# Label 'pancreas_120.nii.gz' has 104 label channels.
# Image 'pancreas_120.nii.gz' has 2.0 labels.
# Image 'pancreas_041.nii.gz' has 137 image channels.
# Label 'pancreas_041.nii.gz' has 137 label channels.
# Image 'pancreas_041.nii.gz' has 2.0 labels.
# Image 'pancreas_122.nii.gz' has 97 image channels.
# Label 'pancreas_122.nii.gz' has 97 label channels.
# Image 'pancreas_122.nii.gz' has 2.0 labels.
# Image 'pancreas_042.nii.gz' has 51 image channels.
# Label 'pancreas_042.nii.gz' has 51 label channels.
# Image 'pancreas_042.nii.gz' has 2.0 labels.
# Image 'pancreas_124.nii.gz' has 82 image channels.
# Label 'pancreas_124.nii.gz' has 82 label channels.
# Image 'pancreas_124.nii.gz' has 2.0 labels.
# Image 'pancreas_043.nii.gz' has 39 image channels.
# Label 'pancreas_043.nii.gz' has 39 label channels.
# Image 'pancreas_043.nii.gz' has 2.0 labels.
# Image 'pancreas_125.nii.gz' has 102 image channels.
# Label 'pancreas_125.nii.gz' has 102 label channels.
# Image 'pancreas_125.nii.gz' has 2.0 labels.
# Image 'pancreas_045.nii.gz' has 41 image channels.
# Label 'pancreas_045.nii.gz' has 41 label channels.
# Image 'pancreas_045.nii.gz' has 2.0 labels.
# Image 'pancreas_126.nii.gz' has 73 image channels.
# Label 'pancreas_126.nii.gz' has 73 label channels.
# Image 'pancreas_126.nii.gz' has 2.0 labels.
# Image 'pancreas_046.nii.gz' has 103 image channels.
# Label 'pancreas_046.nii.gz' has 103 label channels.
# Image 'pancreas_046.nii.gz' has 2.0 labels.
# Image 'pancreas_127.nii.gz' has 126 image channels.
# Label 'pancreas_127.nii.gz' has 126 label channels.
# Image 'pancreas_127.nii.gz' has 2.0 labels.
# Image 'pancreas_048.nii.gz' has 121 image channels.
# Label 'pancreas_048.nii.gz' has 121 label channels.
# Image 'pancreas_048.nii.gz' has 2.0 labels.
# Image 'pancreas_129.nii.gz' has 44 image channels.
# Label 'pancreas_129.nii.gz' has 44 label channels.
# Image 'pancreas_129.nii.gz' has 2.0 labels.
# Image 'pancreas_049.nii.gz' has 87 image channels.
# Label 'pancreas_049.nii.gz' has 87 label channels.
# Image 'pancreas_049.nii.gz' has 2.0 labels.
# Image 'pancreas_130.nii.gz' has 130 image channels.
# Label 'pancreas_130.nii.gz' has 130 label channels.
# Image 'pancreas_130.nii.gz' has 2.0 labels.
# Image 'pancreas_050.nii.gz' has 85 image channels.
# Label 'pancreas_050.nii.gz' has 85 label channels.
# Image 'pancreas_050.nii.gz' has 2.0 labels.
# Image 'pancreas_131.nii.gz' has 59 image channels.
# Label 'pancreas_131.nii.gz' has 59 label channels.
# Image 'pancreas_131.nii.gz' has 2.0 labels.
# Image 'pancreas_051.nii.gz' has 99 image channels.
# Label 'pancreas_051.nii.gz' has 99 label channels.
# Image 'pancreas_051.nii.gz' has 2.0 labels.
# Image 'pancreas_135.nii.gz' has 60 image channels.
# Label 'pancreas_135.nii.gz' has 60 label channels.
# Image 'pancreas_135.nii.gz' has 2.0 labels.
# Image 'pancreas_052.nii.gz' has 89 image channels.
# Label 'pancreas_052.nii.gz' has 89 label channels.
# Image 'pancreas_052.nii.gz' has 2.0 labels.
# Image 'pancreas_137.nii.gz' has 85 image channels.
# Label 'pancreas_137.nii.gz' has 85 label channels.
# Image 'pancreas_137.nii.gz' has 2.0 labels.
# Image 'pancreas_055.nii.gz' has 96 image channels.
# Label 'pancreas_055.nii.gz' has 96 label channels.
# Image 'pancreas_055.nii.gz' has 2.0 labels.
# Image 'pancreas_138.nii.gz' has 95 image channels.
# Label 'pancreas_138.nii.gz' has 95 label channels.
# Image 'pancreas_138.nii.gz' has 2.0 labels.
# Image 'pancreas_056.nii.gz' has 84 image channels.
# Label 'pancreas_056.nii.gz' has 84 label channels.
# Image 'pancreas_056.nii.gz' has 2.0 labels.
# Image 'pancreas_140.nii.gz' has 56 image channels.
# Label 'pancreas_140.nii.gz' has 56 label channels.
# Image 'pancreas_140.nii.gz' has 2.0 labels.
# Image 'pancreas_058.nii.gz' has 91 image channels.
# Label 'pancreas_058.nii.gz' has 91 label channels.
# Image 'pancreas_058.nii.gz' has 2.0 labels.
# Image 'pancreas_145.nii.gz' has 93 image channels.
# Label 'pancreas_145.nii.gz' has 93 label channels.
# Image 'pancreas_145.nii.gz' has 2.0 labels.
# Image 'pancreas_061.nii.gz' has 93 image channels.
# Label 'pancreas_061.nii.gz' has 93 label channels.
# Image 'pancreas_061.nii.gz' has 2.0 labels.
# Image 'pancreas_147.nii.gz' has 85 image channels.
# Label 'pancreas_147.nii.gz' has 85 label channels.
# Image 'pancreas_147.nii.gz' has 2.0 labels.
# Image 'pancreas_064.nii.gz' has 93 image channels.
# Label 'pancreas_064.nii.gz' has 93 label channels.
# Image 'pancreas_064.nii.gz' has 2.0 labels.
# Image 'pancreas_148.nii.gz' has 42 image channels.
# Label 'pancreas_148.nii.gz' has 42 label channels.
# Image 'pancreas_148.nii.gz' has 2.0 labels.
# Image 'pancreas_066.nii.gz' has 96 image channels.
# Label 'pancreas_066.nii.gz' has 96 label channels.
# Image 'pancreas_066.nii.gz' has 2.0 labels.
# Image 'pancreas_149.nii.gz' has 77 image channels.
# Label 'pancreas_149.nii.gz' has 77 label channels.
# Image 'pancreas_149.nii.gz' has 2.0 labels.
# Image 'pancreas_067.nii.gz' has 103 image channels.
# Label 'pancreas_067.nii.gz' has 103 label channels.
# Image 'pancreas_067.nii.gz' has 2.0 labels.
# Image 'pancreas_155.nii.gz' has 95 image channels.
# Label 'pancreas_155.nii.gz' has 95 label channels.
# Image 'pancreas_155.nii.gz' has 2.0 labels.
# Image 'pancreas_069.nii.gz' has 97 image channels.
# Label 'pancreas_069.nii.gz' has 97 label channels.
# Image 'pancreas_069.nii.gz' has 2.0 labels.
# Image 'pancreas_157.nii.gz' has 77 image channels.
# Label 'pancreas_157.nii.gz' has 77 label channels.
# Image 'pancreas_157.nii.gz' has 2.0 labels.
# Image 'pancreas_070.nii.gz' has 106 image channels.
# Label 'pancreas_070.nii.gz' has 106 label channels.
# Image 'pancreas_070.nii.gz' has 2.0 labels.
# Image 'pancreas_158.nii.gz' has 66 image channels.
# Label 'pancreas_158.nii.gz' has 66 label channels.
# Image 'pancreas_158.nii.gz' has 2.0 labels.
# Image 'pancreas_071.nii.gz' has 87 image channels.
# Label 'pancreas_071.nii.gz' has 87 label channels.
# Image 'pancreas_071.nii.gz' has 2.0 labels.
# Image 'pancreas_159.nii.gz' has 90 image channels.
# Label 'pancreas_159.nii.gz' has 90 label channels.
# Image 'pancreas_159.nii.gz' has 2.0 labels.
# Image 'pancreas_074.nii.gz' has 37 image channels.
# Label 'pancreas_074.nii.gz' has 37 label channels.
# Image 'pancreas_074.nii.gz' has 2.0 labels.
# Image 'pancreas_160.nii.gz' has 75 image channels.
# Label 'pancreas_160.nii.gz' has 75 label channels.
# Image 'pancreas_160.nii.gz' has 2.0 labels.
# Image 'pancreas_075.nii.gz' has 121 image channels.
# Label 'pancreas_075.nii.gz' has 121 label channels.
# Image 'pancreas_075.nii.gz' has 2.0 labels.
# Image 'pancreas_165.nii.gz' has 85 image channels.
# Label 'pancreas_165.nii.gz' has 85 label channels.
# Image 'pancreas_165.nii.gz' has 2.0 labels.
# Image 'pancreas_077.nii.gz' has 81 image channels.
# Label 'pancreas_077.nii.gz' has 81 label channels.
# Image 'pancreas_077.nii.gz' has 2.0 labels.
# Image 'pancreas_166.nii.gz' has 95 image channels.
# Label 'pancreas_166.nii.gz' has 95 label channels.
# Image 'pancreas_166.nii.gz' has 2.0 labels.
# Image 'pancreas_078.nii.gz' has 76 image channels.
# Label 'pancreas_078.nii.gz' has 76 label channels.
# Image 'pancreas_078.nii.gz' has 2.0 labels.
# Image 'pancreas_167.nii.gz' has 101 image channels.
# Label 'pancreas_167.nii.gz' has 101 label channels.
# Image 'pancreas_167.nii.gz' has 2.0 labels.
# Image 'pancreas_080.nii.gz' has 98 image channels.
# Label 'pancreas_080.nii.gz' has 98 label channels.
# Image 'pancreas_080.nii.gz' has 2.0 labels.
# Image 'pancreas_169.nii.gz' has 87 image channels.
# Label 'pancreas_169.nii.gz' has 87 label channels.
# Image 'pancreas_169.nii.gz' has 2.0 labels.
# Image 'pancreas_081.nii.gz' has 47 image channels.
# Label 'pancreas_081.nii.gz' has 47 label channels.
# Image 'pancreas_081.nii.gz' has 2.0 labels.
# Image 'pancreas_170.nii.gz' has 103 image channels.
# Label 'pancreas_170.nii.gz' has 103 label channels.
# Image 'pancreas_170.nii.gz' has 2.0 labels.
# Image 'pancreas_083.nii.gz' has 83 image channels.
# Label 'pancreas_083.nii.gz' has 83 label channels.
# Image 'pancreas_083.nii.gz' has 2.0 labels.
# Image 'pancreas_172.nii.gz' has 95 image channels.
# Label 'pancreas_172.nii.gz' has 95 label channels.
# Image 'pancreas_172.nii.gz' has 2.0 labels.
# Image 'pancreas_084.nii.gz' has 82 image channels.
# Label 'pancreas_084.nii.gz' has 82 label channels.
# Image 'pancreas_084.nii.gz' has 2.0 labels.
# Image 'pancreas_173.nii.gz' has 81 image channels.
# Label 'pancreas_173.nii.gz' has 81 label channels.
# Image 'pancreas_173.nii.gz' has 2.0 labels.
# Image 'pancreas_086.nii.gz' has 51 image channels.
# Label 'pancreas_086.nii.gz' has 51 label channels.
# Image 'pancreas_086.nii.gz' has 2.0 labels.
# Image 'pancreas_096.nii.gz' has 108 image channels.
# Label 'pancreas_096.nii.gz' has 108 label channels.
# Image 'pancreas_096.nii.gz' has 2.0 labels.
# Image 'pancreas_175.nii.gz' has 91 image channels.
# Label 'pancreas_175.nii.gz' has 91 label channels.
# Image 'pancreas_175.nii.gz' has 2.0 labels.
# Image 'pancreas_098.nii.gz' has 147 image channels.
# Label 'pancreas_098.nii.gz' has 147 label channels.
# Image 'pancreas_098.nii.gz' has 2.0 labels.
# Image 'pancreas_178.nii.gz' has 110 image channels.
# Label 'pancreas_178.nii.gz' has 110 label channels.
# Image 'pancreas_178.nii.gz' has 2.0 labels.
# Image 'pancreas_099.nii.gz' has 48 image channels.
# Label 'pancreas_099.nii.gz' has 48 label channels.
# Image 'pancreas_099.nii.gz' has 2.0 labels.
# Image 'pancreas_179.nii.gz' has 89 image channels.
# Label 'pancreas_179.nii.gz' has 89 label channels.
# Image 'pancreas_179.nii.gz' has 2.0 labels.
# Image 'pancreas_100.nii.gz' has 98 image channels.
# Label 'pancreas_100.nii.gz' has 98 label channels.
# Image 'pancreas_100.nii.gz' has 2.0 labels.
# Image 'pancreas_180.nii.gz' has 95 image channels.
# Label 'pancreas_180.nii.gz' has 95 label channels.
# Image 'pancreas_180.nii.gz' has 2.0 labels.
# Image 'pancreas_101.nii.gz' has 98 image channels.
# Label 'pancreas_101.nii.gz' has 98 label channels.
# Image 'pancreas_101.nii.gz' has 2.0 labels.
# Image 'pancreas_181.nii.gz' has 87 image channels.
# Label 'pancreas_181.nii.gz' has 87 label channels.
# Image 'pancreas_181.nii.gz' has 2.0 labels.
# Image 'pancreas_102.nii.gz' has 92 image channels.
# Label 'pancreas_102.nii.gz' has 92 label channels.
# Image 'pancreas_102.nii.gz' has 2.0 labels.
# Image 'pancreas_103.nii.gz' has 90 image channels.
# Label 'pancreas_103.nii.gz' has 90 label channels.
# Image 'pancreas_103.nii.gz' has 2.0 labels.
# Image 'pancreas_183.nii.gz' has 76 image channels.
# Label 'pancreas_183.nii.gz' has 76 label channels.
# Image 'pancreas_183.nii.gz' has 2.0 labels.
# Image 'pancreas_186.nii.gz' has 51 image channels.
# Label 'pancreas_186.nii.gz' has 51 label channels.
# Image 'pancreas_186.nii.gz' has 2.0 labels.
# Image 'pancreas_187.nii.gz' has 95 image channels.
# Label 'pancreas_187.nii.gz' has 95 label channels.
# Image 'pancreas_187.nii.gz' has 2.0 labels.
# Image 'pancreas_191.nii.gz' has 57 image channels.
# Label 'pancreas_191.nii.gz' has 57 label channels.
# Image 'pancreas_191.nii.gz' has 2.0 labels.
# Image 'pancreas_193.nii.gz' has 113 image channels.
# Label 'pancreas_193.nii.gz' has 113 label channels.
# Image 'pancreas_193.nii.gz' has 2.0 labels.
# Image 'pancreas_194.nii.gz' has 98 image channels.
# Label 'pancreas_194.nii.gz' has 98 label channels.
# Image 'pancreas_194.nii.gz' has 2.0 labels.
# Image 'pancreas_196.nii.gz' has 92 image channels.
# Label 'pancreas_196.nii.gz' has 92 label channels.
# Image 'pancreas_196.nii.gz' has 2.0 labels.
# Image 'pancreas_197.nii.gz' has 73 image channels.
# Label 'pancreas_197.nii.gz' has 73 label channels.
# Image 'pancreas_197.nii.gz' has 2.0 labels.
# Image 'pancreas_198.nii.gz' has 111 image channels.
# Label 'pancreas_198.nii.gz' has 111 label channels.
# Image 'pancreas_198.nii.gz' has 2.0 labels.
# Image 'pancreas_199.nii.gz' has 95 image channels.
# Label 'pancreas_199.nii.gz' has 95 label channels.
# Image 'pancreas_199.nii.gz' has 2.0 labels.
# Image 'pancreas_200.nii.gz' has 89 image channels.
# Label 'pancreas_200.nii.gz' has 89 label channels.
# Image 'pancreas_200.nii.gz' has 2.0 labels.
# Image 'pancreas_201.nii.gz' has 76 image channels.
# Label 'pancreas_201.nii.gz' has 76 label channels.
# Image 'pancreas_201.nii.gz' has 2.0 labels.
# Image 'pancreas_203.nii.gz' has 106 image channels.
# Label 'pancreas_203.nii.gz' has 106 label channels.
# Image 'pancreas_203.nii.gz' has 2.0 labels.
# Image 'pancreas_204.nii.gz' has 73 image channels.
# Label 'pancreas_204.nii.gz' has 73 label channels.
# Image 'pancreas_204.nii.gz' has 2.0 labels.
# Image 'pancreas_207.nii.gz' has 81 image channels.
# Label 'pancreas_207.nii.gz' has 81 label channels.
# Image 'pancreas_207.nii.gz' has 2.0 labels.
# Image 'pancreas_209.nii.gz' has 104 image channels.
# Label 'pancreas_209.nii.gz' has 104 label channels.
# Image 'pancreas_209.nii.gz' has 2.0 labels.
# Image 'pancreas_210.nii.gz' has 93 image channels.
# Label 'pancreas_210.nii.gz' has 93 label channels.
# Image 'pancreas_210.nii.gz' has 2.0 labels.
# Image 'pancreas_211.nii.gz' has 121 image channels.
# Label 'pancreas_211.nii.gz' has 121 label channels.
# Image 'pancreas_211.nii.gz' has 2.0 labels.
# Image 'pancreas_212.nii.gz' has 97 image channels.
# Label 'pancreas_212.nii.gz' has 97 label channels.
# Image 'pancreas_212.nii.gz' has 2.0 labels.
# Image 'pancreas_213.nii.gz' has 95 image channels.
# Label 'pancreas_213.nii.gz' has 95 label channels.
# Image 'pancreas_213.nii.gz' has 2.0 labels.
# Image 'pancreas_214.nii.gz' has 109 image channels.
# Label 'pancreas_214.nii.gz' has 109 label channels.
# Image 'pancreas_214.nii.gz' has 2.0 labels.
# Image 'pancreas_215.nii.gz' has 99 image channels.
# Label 'pancreas_215.nii.gz' has 99 label channels.
# Image 'pancreas_215.nii.gz' has 2.0 labels.
# Image 'pancreas_217.nii.gz' has 107 image channels.
# Label 'pancreas_217.nii.gz' has 107 label channels.
# Image 'pancreas_217.nii.gz' has 2.0 labels.
# Image 'pancreas_218.nii.gz' has 99 image channels.
# Label 'pancreas_218.nii.gz' has 99 label channels.
# Image 'pancreas_218.nii.gz' has 2.0 labels.
# Image 'pancreas_219.nii.gz' has 192 image channels.
# Label 'pancreas_219.nii.gz' has 192 label channels.
# Image 'pancreas_219.nii.gz' has 2.0 labels.
# Image 'pancreas_222.nii.gz' has 77 image channels.
# Label 'pancreas_222.nii.gz' has 77 label channels.
# Image 'pancreas_222.nii.gz' has 2.0 labels.
# Image 'pancreas_224.nii.gz' has 93 image channels.
# Label 'pancreas_224.nii.gz' has 93 label channels.
# Image 'pancreas_224.nii.gz' has 2.0 labels.
# Image 'pancreas_225.nii.gz' has 81 image channels.
# Label 'pancreas_225.nii.gz' has 81 label channels.
# Image 'pancreas_225.nii.gz' has 2.0 labels.
# Image 'pancreas_226.nii.gz' has 104 image channels.
# Label 'pancreas_226.nii.gz' has 104 label channels.
# Image 'pancreas_226.nii.gz' has 2.0 labels.
# Image 'pancreas_227.nii.gz' has 89 image channels.
# Label 'pancreas_227.nii.gz' has 89 label channels.
# Image 'pancreas_227.nii.gz' has 2.0 labels.
# Image 'pancreas_228.nii.gz' has 113 image channels.
# Label 'pancreas_228.nii.gz' has 113 label channels.
# Image 'pancreas_228.nii.gz' has 2.0 labels.
# Image 'pancreas_229.nii.gz' has 87 image channels.
# Label 'pancreas_229.nii.gz' has 87 label channels.
# Image 'pancreas_229.nii.gz' has 2.0 labels.
# Image 'pancreas_230.nii.gz' has 96 image channels.
# Label 'pancreas_230.nii.gz' has 96 label channels.
# Image 'pancreas_230.nii.gz' has 2.0 labels.
# Image 'pancreas_231.nii.gz' has 93 image channels.
# Label 'pancreas_231.nii.gz' has 93 label channels.
# Image 'pancreas_231.nii.gz' has 2.0 labels.
# Image 'pancreas_234.nii.gz' has 81 image channels.
# Label 'pancreas_234.nii.gz' has 81 label channels.
# Image 'pancreas_234.nii.gz' has 2.0 labels.
# Image 'pancreas_235.nii.gz' has 84 image channels.
# Label 'pancreas_235.nii.gz' has 84 label channels.
# Image 'pancreas_235.nii.gz' has 2.0 labels.
# Image 'pancreas_236.nii.gz' has 81 image channels.
# Label 'pancreas_236.nii.gz' has 81 label channels.
# Image 'pancreas_236.nii.gz' has 2.0 labels.
# Image 'pancreas_239.nii.gz' has 92 image channels.
# Label 'pancreas_239.nii.gz' has 92 label channels.
# Image 'pancreas_239.nii.gz' has 2.0 labels.
# Image 'pancreas_241.nii.gz' has 99 image channels.
# Label 'pancreas_241.nii.gz' has 99 label channels.
# Image 'pancreas_241.nii.gz' has 2.0 labels.
# Image 'pancreas_242.nii.gz' has 101 image channels.
# Label 'pancreas_242.nii.gz' has 101 label channels.
# Image 'pancreas_242.nii.gz' has 2.0 labels.
# Image 'pancreas_243.nii.gz' has 51 image channels.
# Label 'pancreas_243.nii.gz' has 51 label channels.
# Image 'pancreas_243.nii.gz' has 2.0 labels.
# Image 'pancreas_244.nii.gz' has 103 image channels.
# Label 'pancreas_244.nii.gz' has 103 label channels.
# Image 'pancreas_244.nii.gz' has 2.0 labels.
# Image 'pancreas_246.nii.gz' has 107 image channels.
# Label 'pancreas_246.nii.gz' has 107 label channels.
# Image 'pancreas_246.nii.gz' has 2.0 labels.
# Image 'pancreas_247.nii.gz' has 89 image channels.
# Label 'pancreas_247.nii.gz' has 89 label channels.
# Image 'pancreas_247.nii.gz' has 2.0 labels.
# Image 'pancreas_249.nii.gz' has 123 image channels.
# Label 'pancreas_249.nii.gz' has 123 label channels.
# Image 'pancreas_249.nii.gz' has 2.0 labels.
# Image 'pancreas_253.nii.gz' has 94 image channels.
# Label 'pancreas_253.nii.gz' has 94 label channels.
# Image 'pancreas_253.nii.gz' has 2.0 labels.
# Image 'pancreas_254.nii.gz' has 101 image channels.
# Label 'pancreas_254.nii.gz' has 101 label channels.
# Image 'pancreas_254.nii.gz' has 2.0 labels.
# Image 'pancreas_255.nii.gz' has 99 image channels.
# Label 'pancreas_255.nii.gz' has 99 label channels.
# Image 'pancreas_255.nii.gz' has 2.0 labels.
# Image 'pancreas_256.nii.gz' has 89 image channels.
# Label 'pancreas_256.nii.gz' has 89 label channels.
# Image 'pancreas_256.nii.gz' has 2.0 labels.
# Image 'pancreas_258.nii.gz' has 79 image channels.
# Label 'pancreas_258.nii.gz' has 79 label channels.
# Image 'pancreas_258.nii.gz' has 2.0 labels.
# Image 'pancreas_259.nii.gz' has 88 image channels.
# Label 'pancreas_259.nii.gz' has 88 label channels.
# Image 'pancreas_259.nii.gz' has 2.0 labels.
# Image 'pancreas_261.nii.gz' has 161 image channels.
# Label 'pancreas_261.nii.gz' has 161 label channels.
# Image 'pancreas_261.nii.gz' has 2.0 labels.
# Image 'pancreas_262.nii.gz' has 76 image channels.
# Label 'pancreas_262.nii.gz' has 76 label channels.
# Image 'pancreas_262.nii.gz' has 2.0 labels.
# Image 'pancreas_264.nii.gz' has 109 image channels.
# Label 'pancreas_264.nii.gz' has 109 label channels.
# Image 'pancreas_264.nii.gz' has 2.0 labels.
# Image 'pancreas_265.nii.gz' has 81 image channels.
# Label 'pancreas_265.nii.gz' has 81 label channels.
# Image 'pancreas_265.nii.gz' has 2.0 labels.
# Image 'pancreas_266.nii.gz' has 97 image channels.
# Label 'pancreas_266.nii.gz' has 97 label channels.
# Image 'pancreas_266.nii.gz' has 2.0 labels.
# Image 'pancreas_267.nii.gz' has 89 image channels.
# Label 'pancreas_267.nii.gz' has 89 label channels.
# Image 'pancreas_267.nii.gz' has 2.0 labels.
# Image 'pancreas_268.nii.gz' has 67 image channels.
# Label 'pancreas_268.nii.gz' has 67 label channels.
# Image 'pancreas_268.nii.gz' has 2.0 labels.
# Image 'pancreas_269.nii.gz' has 113 image channels.
# Label 'pancreas_269.nii.gz' has 113 label channels.
# Image 'pancreas_269.nii.gz' has 2.0 labels.
# Image 'pancreas_270.nii.gz' has 87 image channels.
# Label 'pancreas_270.nii.gz' has 87 label channels.
# Image 'pancreas_270.nii.gz' has 2.0 labels.
# Image 'pancreas_274.nii.gz' has 115 image channels.
# Label 'pancreas_274.nii.gz' has 115 label channels.
# Image 'pancreas_274.nii.gz' has 2.0 labels.
# Image 'pancreas_275.nii.gz' has 105 image channels.
# Label 'pancreas_275.nii.gz' has 105 label channels.
# Image 'pancreas_275.nii.gz' has 2.0 labels.
# Image 'pancreas_276.nii.gz' has 89 image channels.
# Label 'pancreas_276.nii.gz' has 89 label channels.
# Image 'pancreas_276.nii.gz' has 2.0 labels.
# Image 'pancreas_277.nii.gz' has 109 image channels.
# Label 'pancreas_277.nii.gz' has 109 label channels.
# Image 'pancreas_277.nii.gz' has 2.0 labels.
# Image 'pancreas_278.nii.gz' has 100 image channels.
# Label 'pancreas_278.nii.gz' has 100 label channels.
# Image 'pancreas_278.nii.gz' has 2.0 labels.
# Image 'pancreas_279.nii.gz' has 80 image channels.
# Label 'pancreas_279.nii.gz' has 80 label channels.
# Image 'pancreas_279.nii.gz' has 2.0 labels.
# Image 'pancreas_280.nii.gz' has 97 image channels.
# Label 'pancreas_280.nii.gz' has 97 label channels.
# Image 'pancreas_280.nii.gz' has 2.0 labels.
# Image 'pancreas_283.nii.gz' has 107 image channels.
# Label 'pancreas_283.nii.gz' has 107 label channels.
# Image 'pancreas_283.nii.gz' has 2.0 labels.
# Image 'pancreas_284.nii.gz' has 85 image channels.
# Label 'pancreas_284.nii.gz' has 85 label channels.
# Image 'pancreas_284.nii.gz' has 2.0 labels.
# Image 'pancreas_285.nii.gz' has 113 image channels.
# Label 'pancreas_285.nii.gz' has 113 label channels.
# Image 'pancreas_285.nii.gz' has 2.0 labels.
# Image 'pancreas_286.nii.gz' has 93 image channels.
# Label 'pancreas_286.nii.gz' has 93 label channels.
# Image 'pancreas_286.nii.gz' has 2.0 labels.
# Image 'pancreas_287.nii.gz' has 98 image channels.
# Label 'pancreas_287.nii.gz' has 98 label channels.
# Image 'pancreas_287.nii.gz' has 2.0 labels.
# Image 'pancreas_289.nii.gz' has 96 image channels.
# Label 'pancreas_289.nii.gz' has 96 label channels.
# Image 'pancreas_289.nii.gz' has 2.0 labels.
# Image 'pancreas_290.nii.gz' has 97 image channels.
# Label 'pancreas_290.nii.gz' has 97 label channels.
# Image 'pancreas_290.nii.gz' has 2.0 labels.
# Image 'pancreas_291.nii.gz' has 97 image channels.
# Label 'pancreas_291.nii.gz' has 97 label channels.
# Image 'pancreas_291.nii.gz' has 2.0 labels.
# Image 'pancreas_292.nii.gz' has 93 image channels.
# Label 'pancreas_292.nii.gz' has 93 label channels.
# Image 'pancreas_292.nii.gz' has 2.0 labels.
# Image 'pancreas_293.nii.gz' has 107 image channels.
# Label 'pancreas_293.nii.gz' has 107 label channels.
# Image 'pancreas_293.nii.gz' has 2.0 labels.
# Image 'pancreas_294.nii.gz' has 97 image channels.
# Label 'pancreas_294.nii.gz' has 97 label channels.
# Image 'pancreas_294.nii.gz' has 2.0 labels.
# Image 'pancreas_295.nii.gz' has 105 image channels.
# Label 'pancreas_295.nii.gz' has 105 label channels.
# Image 'pancreas_295.nii.gz' has 2.0 labels.
# Image 'pancreas_296.nii.gz' has 43 image channels.
# Label 'pancreas_296.nii.gz' has 43 label channels.
# Image 'pancreas_296.nii.gz' has 2.0 labels.
# Image 'pancreas_297.nii.gz' has 101 image channels.
# Label 'pancreas_297.nii.gz' has 101 label channels.
# Image 'pancreas_297.nii.gz' has 2.0 labels.
# Image 'pancreas_298.nii.gz' has 93 image channels.
# Label 'pancreas_298.nii.gz' has 93 label channels.
# Image 'pancreas_298.nii.gz' has 2.0 labels.
# Image 'pancreas_299.nii.gz' has 83 image channels.
# Label 'pancreas_299.nii.gz' has 83 label channels.
# Image 'pancreas_299.nii.gz' has 2.0 labels.
# Image 'pancreas_300.nii.gz' has 85 image channels.
# Label 'pancreas_300.nii.gz' has 85 label channels.
# Image 'pancreas_300.nii.gz' has 2.0 labels.
# Image 'pancreas_301.nii.gz' has 83 image channels.
# Label 'pancreas_301.nii.gz' has 83 label channels.
# Image 'pancreas_301.nii.gz' has 2.0 labels.
# Image 'pancreas_302.nii.gz' has 83 image channels.
# Label 'pancreas_302.nii.gz' has 83 label channels.
# Image 'pancreas_302.nii.gz' has 2.0 labels.
# Image 'pancreas_303.nii.gz' has 113 image channels.
# Label 'pancreas_303.nii.gz' has 113 label channels.
# Image 'pancreas_303.nii.gz' has 2.0 labels.
# Image 'pancreas_304.nii.gz' has 93 image channels.
# Label 'pancreas_304.nii.gz' has 93 label channels.
# Image 'pancreas_304.nii.gz' has 2.0 labels.
# Image 'pancreas_305.nii.gz' has 73 image channels.
# Label 'pancreas_305.nii.gz' has 73 label channels.
# Image 'pancreas_305.nii.gz' has 2.0 labels.
# Image 'pancreas_308.nii.gz' has 113 image channels.
# Label 'pancreas_308.nii.gz' has 113 label channels.
# Image 'pancreas_308.nii.gz' has 2.0 labels.
# Image 'pancreas_309.nii.gz' has 95 image channels.
# Label 'pancreas_309.nii.gz' has 95 label channels.
# Image 'pancreas_309.nii.gz' has 2.0 labels.
# Image 'pancreas_310.nii.gz' has 81 image channels.
# Label 'pancreas_310.nii.gz' has 81 label channels.
# Image 'pancreas_310.nii.gz' has 2.0 labels.
# Image 'pancreas_311.nii.gz' has 87 image channels.
# Label 'pancreas_311.nii.gz' has 87 label channels.
# Image 'pancreas_311.nii.gz' has 2.0 labels.
# Image 'pancreas_312.nii.gz' has 75 image channels.
# Label 'pancreas_312.nii.gz' has 75 label channels.
# Image 'pancreas_312.nii.gz' has 2.0 labels.
# Image 'pancreas_313.nii.gz' has 95 image channels.
# Label 'pancreas_313.nii.gz' has 95 label channels.
# Image 'pancreas_313.nii.gz' has 2.0 labels.
# Image 'pancreas_315.nii.gz' has 93 image channels.
# Label 'pancreas_315.nii.gz' has 93 label channels.
# Image 'pancreas_315.nii.gz' has 2.0 labels.
# Image 'pancreas_316.nii.gz' has 89 image channels.
# Label 'pancreas_316.nii.gz' has 89 label channels.
# Image 'pancreas_316.nii.gz' has 2.0 labels.
# Image 'pancreas_318.nii.gz' has 105 image channels.
# Label 'pancreas_318.nii.gz' has 105 label channels.
# Image 'pancreas_318.nii.gz' has 2.0 labels.
# Image 'pancreas_320.nii.gz' has 91 image channels.
# Label 'pancreas_320.nii.gz' has 91 label channels.
# Image 'pancreas_320.nii.gz' has 2.0 labels.
# Image 'pancreas_321.nii.gz' has 117 image channels.
# Label 'pancreas_321.nii.gz' has 117 label channels.
# Image 'pancreas_321.nii.gz' has 2.0 labels.
# Image 'pancreas_323.nii.gz' has 95 image channels.
# Label 'pancreas_323.nii.gz' has 95 label channels.
# Image 'pancreas_323.nii.gz' has 2.0 labels.
# Image 'pancreas_325.nii.gz' has 93 image channels.
# Label 'pancreas_325.nii.gz' has 93 label channels.
# Image 'pancreas_325.nii.gz' has 2.0 labels.
# Image 'pancreas_326.nii.gz' has 89 image channels.
# Label 'pancreas_326.nii.gz' has 89 label channels.
# Image 'pancreas_326.nii.gz' has 2.0 labels.
# Image 'pancreas_327.nii.gz' has 99 image channels.
# Label 'pancreas_327.nii.gz' has 99 label channels.
# Image 'pancreas_327.nii.gz' has 2.0 labels.
# Image 'pancreas_328.nii.gz' has 95 image channels.
# Label 'pancreas_328.nii.gz' has 95 label channels.
# Image 'pancreas_328.nii.gz' has 2.0 labels.
# Image 'pancreas_329.nii.gz' has 79 image channels.
# Label 'pancreas_329.nii.gz' has 79 label channels.
# Image 'pancreas_329.nii.gz' has 2.0 labels.
# Image 'pancreas_330.nii.gz' has 89 image channels.
# Label 'pancreas_330.nii.gz' has 89 label channels.
# Image 'pancreas_330.nii.gz' has 2.0 labels.
# Image 'pancreas_331.nii.gz' has 101 image channels.
# Label 'pancreas_331.nii.gz' has 101 label channels.
# Image 'pancreas_331.nii.gz' has 2.0 labels.
# Image 'pancreas_333.nii.gz' has 97 image channels.
# Label 'pancreas_333.nii.gz' has 97 label channels.
# Image 'pancreas_333.nii.gz' has 2.0 labels.
# Image 'pancreas_334.nii.gz' has 91 image channels.
# Label 'pancreas_334.nii.gz' has 91 label channels.
# Image 'pancreas_334.nii.gz' has 2.0 labels.
# Image 'pancreas_336.nii.gz' has 92 image channels.
# Label 'pancreas_336.nii.gz' has 92 label channels.
# Image 'pancreas_336.nii.gz' has 2.0 labels.
# Image 'pancreas_339.nii.gz' has 105 image channels.
# Label 'pancreas_339.nii.gz' has 105 label channels.
# Image 'pancreas_339.nii.gz' has 2.0 labels.
# Image 'pancreas_342.nii.gz' has 117 image channels.
# Label 'pancreas_342.nii.gz' has 117 label channels.
# Image 'pancreas_342.nii.gz' has 2.0 labels.
# Image 'pancreas_343.nii.gz' has 86 image channels.
# Label 'pancreas_343.nii.gz' has 86 label channels.
# Image 'pancreas_343.nii.gz' has 2.0 labels.
# Image 'pancreas_344.nii.gz' has 112 image channels.
# Label 'pancreas_344.nii.gz' has 112 label channels.
# Image 'pancreas_344.nii.gz' has 2.0 labels.
# Image 'pancreas_345.nii.gz' has 84 image channels.
# Label 'pancreas_345.nii.gz' has 84 label channels.
# Image 'pancreas_345.nii.gz' has 2.0 labels.
# Image 'pancreas_346.nii.gz' has 103 image channels.
# Label 'pancreas_346.nii.gz' has 103 label channels.
# Image 'pancreas_346.nii.gz' has 2.0 labels.
# Image 'pancreas_347.nii.gz' has 89 image channels.
# Label 'pancreas_347.nii.gz' has 89 label channels.
# Image 'pancreas_347.nii.gz' has 2.0 labels.
# Image 'pancreas_348.nii.gz' has 89 image channels.
# Label 'pancreas_348.nii.gz' has 89 label channels.
# Image 'pancreas_348.nii.gz' has 2.0 labels.
# Image 'pancreas_350.nii.gz' has 89 image channels.
# Label 'pancreas_350.nii.gz' has 89 label channels.
# Image 'pancreas_350.nii.gz' has 2.0 labels.
# Image 'pancreas_351.nii.gz' has 88 image channels.
# Label 'pancreas_351.nii.gz' has 88 label channels.
# Image 'pancreas_351.nii.gz' has 2.0 labels.
# Image 'pancreas_354.nii.gz' has 81 image channels.
# Label 'pancreas_354.nii.gz' has 81 label channels.
# Image 'pancreas_354.nii.gz' has 2.0 labels.
# Image 'pancreas_355.nii.gz' has 86 image channels.
# Label 'pancreas_355.nii.gz' has 86 label channels.
# Image 'pancreas_355.nii.gz' has 2.0 labels.
# Image 'pancreas_356.nii.gz' has 84 image channels.
# Label 'pancreas_356.nii.gz' has 84 label channels.
# Image 'pancreas_356.nii.gz' has 2.0 labels.
# Image 'pancreas_357.nii.gz' has 44 image channels.
# Label 'pancreas_357.nii.gz' has 44 label channels.
# Image 'pancreas_357.nii.gz' has 2.0 labels.
# Image 'pancreas_358.nii.gz' has 89 image channels.
# Label 'pancreas_358.nii.gz' has 89 label channels.
# Image 'pancreas_358.nii.gz' has 2.0 labels.
# Image 'pancreas_360.nii.gz' has 40 image channels.
# Label 'pancreas_360.nii.gz' has 40 label channels.
# Image 'pancreas_360.nii.gz' has 2.0 labels.
# Image 'pancreas_361.nii.gz' has 68 image channels.
# Label 'pancreas_361.nii.gz' has 68 label channels.
# Image 'pancreas_361.nii.gz' has 2.0 labels.
# Image 'pancreas_362.nii.gz' has 48 image channels.
# Label 'pancreas_362.nii.gz' has 48 label channels.
# Image 'pancreas_362.nii.gz' has 2.0 labels.
# Image 'pancreas_364.nii.gz' has 89 image channels.
# Label 'pancreas_364.nii.gz' has 89 label channels.
# Image 'pancreas_364.nii.gz' has 2.0 labels.
# Image 'pancreas_365.nii.gz' has 94 image channels.
# Label 'pancreas_365.nii.gz' has 94 label channels.
# Image 'pancreas_365.nii.gz' has 2.0 labels.
# Image 'pancreas_366.nii.gz' has 121 image channels.
# Label 'pancreas_366.nii.gz' has 121 label channels.
# Image 'pancreas_366.nii.gz' has 2.0 labels.
# Image 'pancreas_367.nii.gz' has 104 image channels.
# Label 'pancreas_367.nii.gz' has 104 label channels.
# Image 'pancreas_367.nii.gz' has 2.0 labels.
# Image 'pancreas_369.nii.gz' has 97 image channels.
# Label 'pancreas_369.nii.gz' has 97 label channels.
# Image 'pancreas_369.nii.gz' has 2.0 labels.
# Image 'pancreas_370.nii.gz' has 91 image channels.
# Label 'pancreas_370.nii.gz' has 91 label channels.
# Image 'pancreas_370.nii.gz' has 2.0 labels.
# Image 'pancreas_372.nii.gz' has 93 image channels.
# Label 'pancreas_372.nii.gz' has 93 label channels.
# Image 'pancreas_372.nii.gz' has 2.0 labels.
# Image 'pancreas_374.nii.gz' has 137 image channels.
# Label 'pancreas_374.nii.gz' has 137 label channels.
# Image 'pancreas_374.nii.gz' has 2.0 labels.
# Image 'pancreas_375.nii.gz' has 117 image channels.
# Label 'pancreas_375.nii.gz' has 117 label channels.
# Image 'pancreas_375.nii.gz' has 2.0 labels.
# Image 'pancreas_376.nii.gz' has 109 image channels.
# Label 'pancreas_376.nii.gz' has 109 label channels.
# Image 'pancreas_376.nii.gz' has 2.0 labels.
# Image 'pancreas_377.nii.gz' has 55 image channels.
# Label 'pancreas_377.nii.gz' has 55 label channels.
# Image 'pancreas_377.nii.gz' has 2.0 labels.
# Image 'pancreas_378.nii.gz' has 93 image channels.
# Label 'pancreas_378.nii.gz' has 93 label channels.
# Image 'pancreas_378.nii.gz' has 2.0 labels.
# Image 'pancreas_379.nii.gz' has 384 image channels.
# Label 'pancreas_379.nii.gz' has 384 label channels.
# Image 'pancreas_379.nii.gz' has 2.0 labels.
# Image 'pancreas_380.nii.gz' has 63 image channels.
# Label 'pancreas_380.nii.gz' has 63 label channels.
# Image 'pancreas_380.nii.gz' has 2.0 labels.
# Image 'pancreas_382.nii.gz' has 111 image channels.
# Label 'pancreas_382.nii.gz' has 111 label channels.
# Image 'pancreas_382.nii.gz' has 2.0 labels.
# Image 'pancreas_385.nii.gz' has 49 image channels.
# Label 'pancreas_385.nii.gz' has 49 label channels.
# Image 'pancreas_385.nii.gz' has 2.0 labels.
# Image 'pancreas_386.nii.gz' has 81 image channels.
# Label 'pancreas_386.nii.gz' has 81 label channels.
# Image 'pancreas_386.nii.gz' has 2.0 labels.
# Image 'pancreas_387.nii.gz' has 50 image channels.
# Label 'pancreas_387.nii.gz' has 50 label channels.
# Image 'pancreas_387.nii.gz' has 2.0 labels.
# Image 'pancreas_388.nii.gz' has 57 image channels.
# Label 'pancreas_388.nii.gz' has 57 label channels.
# Image 'pancreas_388.nii.gz' has 2.0 labels.
# Image 'pancreas_389.nii.gz' has 118 image channels.
# Label 'pancreas_389.nii.gz' has 118 label channels.
# Image 'pancreas_389.nii.gz' has 2.0 labels.
# Image 'pancreas_391.nii.gz' has 89 image channels.
# Label 'pancreas_391.nii.gz' has 89 label channels.
# Image 'pancreas_391.nii.gz' has 2.0 labels.
# Image 'pancreas_392.nii.gz' has 57 image channels.
# Label 'pancreas_392.nii.gz' has 57 label channels.
# Image 'pancreas_392.nii.gz' has 2.0 labels.
# Image 'pancreas_393.nii.gz' has 119 image channels.
# Label 'pancreas_393.nii.gz' has 119 label channels.
# Image 'pancreas_393.nii.gz' has 2.0 labels.
# Image 'pancreas_395.nii.gz' has 142 image channels.
# Label 'pancreas_395.nii.gz' has 142 label channels.
# Image 'pancreas_395.nii.gz' has 2.0 labels.
# Image 'pancreas_398.nii.gz' has 103 image channels.
# Label 'pancreas_398.nii.gz' has 103 label channels.
# Image 'pancreas_398.nii.gz' has 2.0 labels.
# Image 'pancreas_399.nii.gz' has 58 image channels.
# Label 'pancreas_399.nii.gz' has 58 label channels.
# Image 'pancreas_399.nii.gz' has 2.0 labels.
# Image 'pancreas_400.nii.gz' has 107 image channels.
# Label 'pancreas_400.nii.gz' has 107 label channels.
# Image 'pancreas_400.nii.gz' has 2.0 labels.
# Image 'pancreas_401.nii.gz' has 120 image channels.
# Label 'pancreas_401.nii.gz' has 120 label channels.
# Image 'pancreas_401.nii.gz' has 2.0 labels.
# Image 'pancreas_402.nii.gz' has 134 image channels.
# Label 'pancreas_402.nii.gz' has 134 label channels.
# Image 'pancreas_402.nii.gz' has 2.0 labels.
# Image 'pancreas_404.nii.gz' has 105 image channels.
# Label 'pancreas_404.nii.gz' has 105 label channels.
# Image 'pancreas_404.nii.gz' has 2.0 labels.
# Image 'pancreas_405.nii.gz' has 89 image channels.
# Label 'pancreas_405.nii.gz' has 89 label channels.
# Image 'pancreas_405.nii.gz' has 2.0 labels.
# Image 'pancreas_406.nii.gz' has 72 image channels.
# Label 'pancreas_406.nii.gz' has 72 label channels.
# Image 'pancreas_406.nii.gz' has 2.0 labels.
# Image 'pancreas_409.nii.gz' has 751 image channels.
# Label 'pancreas_409.nii.gz' has 751 label channels.
# Image 'pancreas_409.nii.gz' has 2.0 labels.
# Image 'pancreas_410.nii.gz' has 101 image channels.
# Label 'pancreas_410.nii.gz' has 101 label channels.
# Image 'pancreas_410.nii.gz' has 2.0 labels.
# Image 'pancreas_411.nii.gz' has 103 image channels.
# Label 'pancreas_411.nii.gz' has 103 label channels.
# Image 'pancreas_411.nii.gz' has 2.0 labels.
# Image 'pancreas_412.nii.gz' has 164 image channels.
# Label 'pancreas_412.nii.gz' has 164 label channels.
# Image 'pancreas_412.nii.gz' has 2.0 labels.
# Image 'pancreas_413.nii.gz' has 85 image channels.
# Label 'pancreas_413.nii.gz' has 85 label channels.
# Image 'pancreas_413.nii.gz' has 2.0 labels.
# Image 'pancreas_414.nii.gz' has 169 image channels.
# Label 'pancreas_414.nii.gz' has 169 label channels.
# Image 'pancreas_414.nii.gz' has 2.0 labels.
# Image 'pancreas_415.nii.gz' has 61 image channels.
# Label 'pancreas_415.nii.gz' has 61 label channels.
# Image 'pancreas_415.nii.gz' has 2.0 labels.
# Image 'pancreas_416.nii.gz' has 116 image channels.
# Label 'pancreas_416.nii.gz' has 116 label channels.
# Image 'pancreas_416.nii.gz' has 2.0 labels.
# Image 'pancreas_418.nii.gz' has 44 image channels.
# Label 'pancreas_418.nii.gz' has 44 label channels.
# Image 'pancreas_418.nii.gz' has 2.0 labels.
# Image 'pancreas_419.nii.gz' has 44 image channels.
# Label 'pancreas_419.nii.gz' has 44 label channels.
# Image 'pancreas_419.nii.gz' has 2.0 labels.
# Image 'pancreas_421.nii.gz' has 131 image channels.
# Label 'pancreas_421.nii.gz' has 131 label channels.
# Image 'pancreas_421.nii.gz' has 2.0 labels.

# %%
class ConvertToMultiChannelPancreasClass(MapTransform):
    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            label = d[key].squeeze(0)  
            stacked_label = torch.stack([label == 1, label == 2], dim=0)
            d[key] = stacked_label.float()
        return d

# %%
train_transform = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    EnsureTyped(keys=["image", "label"]),
    # ConvertToMultiChannelPancreasClass(keys=["label"]),  # Convert label to multiple channels
    NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),  # Normalize image intensities
    ResizeD(keys=["image", "label"], spatial_size=[224, 224, 144], mode=("trilinear", "nearest")),  # Resize image and label
])

val_transform = Compose([
    LoadImaged(keys=["image", "label"]),
    EnsureChannelFirstd(keys=["image", "label"]),
    EnsureTyped(keys=["image", "label"]),
    # ConvertToMultiChannelPancreasClass(keys=["label"]),  # Convert label to multiple channels
    NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),  # Normalize image intensities
    ResizeD(keys=["image", "label"], spatial_size=[224, 224, 144], mode=("trilinear", "nearest")),  # Resize image and label
])

# %%
root_dir =  "/home/"
# here we don't cache any data in case out of memory issue
train_ds = DecathlonDataset(
    root_dir=root_dir,
    task="Task07_Pancreas",
    transform=train_transform,
    section="training",
    download=False,
    cache_rate=0.0,
    num_workers=4,
)
train_loader = DataLoader(train_ds, batch_size=1, shuffle=True, num_workers=4)
val_ds = DecathlonDataset(
    root_dir=root_dir,
    task="Task07_Pancreas",
    transform=val_transform,
    section="validation",
    download=False,
    cache_rate=0.0,
    num_workers=4,
)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=False, num_workers=4)

# %%
import matplotlib.pyplot as plt
for i in range(0,5):
    val_data_example = val_ds[i]
    print(f"image shape: {val_data_example['image'].shape}")
    plt.figure("image and label", (18, 6))

    # Plot the image
    plt.subplot(1, 2, 1)
    plt.title("image")
    plt.imshow(val_data_example["image"][0, :, :, 60].detach().cpu(), cmap="gray")

    # Plot the label with transparency
    label_image = val_data_example["label"][0, :, :, 60].detach().cpu()
    plt.subplot(1, 2, 2)
    plt.title("image + label")
    print(f"label shape: {val_data_example['label'].shape}")
    plt.imshow(val_data_example["image"][0, :, :, 60].detach().cpu(), cmap="gray")
    plt.imshow(label_image, cmap="jet", alpha=0.5)

    plt.show()
# Out:
# image shape: torch.Size([1, 224, 224, 144])
# label shape: torch.Size([1, 224, 224, 144])
# image shape: torch.Size([1, 224, 224, 144])
# label shape: torch.Size([1, 224, 224, 144])
# image shape: torch.Size([1, 224, 224, 144])
# label shape: torch.Size([1, 224, 224, 144])
# image shape: torch.Size([1, 224, 224, 144])
# label shape: torch.Size([1, 224, 224, 144])
# image shape: torch.Size([1, 224, 224, 144])
# label shape: torch.Size([1, 224, 224, 144])

# %%
import matplotlib.pyplot as plt

num_images = 5
image_size = (64, 64)  # Adjust the desired image size

plt.figure(figsize=(8, 6*num_images))
for i in range(num_images):
    val_data_example = train_ds[i]
    plt.subplot(num_images, 4, 4*i + 1)
    plt.title(f"Image {i+1}")
    plt.imshow(val_data_example["image"][0, :, :, 30].detach().cpu(), cmap="gray")
    plt.axis("off")

    for j in range(val_data_example['label'].shape[0]):
        plt.subplot(num_images, 4, 4*i + 2 + j)
        plt.title(f"Label Channel {j+1}")
        plt.imshow(val_data_example["label"][j, :, :, 30].detach().cpu(), cmap="gray")
        plt.axis("off")

plt.tight_layout()
plt.show()

# %%
max_epochs = 30
val_interval = 1
VAL_AMP = True

# standard PyTorch program style: create SegResNet, DiceLoss, and Adam optimizer
device = torch.device("cuda:0")
model = SegResNet(
    blocks_down=[1, 2, 2, 4],
    blocks_up=[1, 1, 1],
    init_filters=16,
    in_channels=1,  # change from 4 to 1
    out_channels=2,  # change from 1 to 2
    dropout_prob=0.2,
).to(device)

loss_function = DiceLoss(smooth_nr=0, smooth_dr=1e-5, squared_pred=True, to_onehot_y=False, sigmoid=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4, weight_decay=1e-5)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

dice_metric = DiceMetric(include_background=True, reduction="mean")
dice_metric_batch = DiceMetric(include_background=True, reduction="mean_batch")

post_trans = Compose([Activations(sigmoid=True), AsDiscrete(threshold=0.5)])


# define inference method
def inference(input):
    def _compute(input):
        return sliding_window_inference(
            inputs=input,
            roi_size=(240, 240, 160),
            sw_batch_size=1,
            predictor=model,
            overlap=0.5,
        )

    if VAL_AMP:
        with torch.cuda.amp.autocast():
            return _compute(input)
    else:
        return _compute(input)


# use amp to accelerate training
scaler = torch.cuda.amp.GradScaler()
# enable cuDNN benchmark
torch.backends.cudnn.benchmark = True

# %%
best_metric = -1
best_metric_epoch = -1
best_metrics_epochs_and_time = [[], [], []]
epoch_loss_values = []
metric_values = []

total_start = time.time()
for epoch in range(max_epochs):
    epoch_start = time.time()
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step_start = time.time()
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        print(f'Input size: {inputs.size()}, label size: {labels.size()}')
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        epoch_loss += loss.item()
        print(
            f"{step}/{len(train_ds) // train_loader.batch_size}"
            f", train_loss: {loss.item():.4f}"
            f", step time: {(time.time() - step_start):.4f}"
        )
    lr_scheduler.step()
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                val_outputs = inference(val_inputs)
                val_outputs = [post_trans(i) for i in decollate_batch(val_outputs)]
                dice_metric(y_pred=val_outputs, y=val_labels)

            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            dice_metric.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                best_metrics_epochs_and_time[0].append(best_metric)
                best_metrics_epochs_and_time[1].append(best_metric_epoch)
                best_metrics_epochs_and_time[2].append(time.time() - total_start)
                torch.save(
                    model.state_dict(),
                    os.path.join(root_dir, "best_metric_model.pth"),
                )
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nbest mean dice: {best_metric:.4f}"
                f" at epoch: {best_metric_epoch}"
            )
    print(f"time consuming of epoch {epoch + 1} is: {(time.time() - epoch_start):.4f}")
total_time = time.time() - total_start
# Out:
# ----------
# epoch 1/30
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py:1295: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/monai/data/__init__.py:120: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   t = cls([], dtype=storage.dtype, device=storage.device)
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py:1295: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py:1295: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py:1295: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# 1/225, train_loss: 0.9947, step time: 2.4625
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 2/225, train_loss: 0.9933, step time: 0.3511
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 3/225, train_loss: 0.9935, step time: 0.3406
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 4/225, train_loss: 0.9953, step time: 0.3380
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 5/225, train_loss: 0.9946, step time: 0.4044
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 6/225, train_loss: 0.9886, step time: 0.3356
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 7/225, train_loss: 0.9922, step time: 0.3375
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 8/225, train_loss: 0.9970, step time: 0.3332
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 9/225, train_loss: 0.9956, step time: 0.3389
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 10/225, train_loss: 0.9935, step time: 0.3382
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 11/225, train_loss: 0.9904, step time: 0.3355
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 12/225, train_loss: 0.9897, step time: 0.3374
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 13/225, train_loss: 0.9943, step time: 0.3367
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 14/225, train_loss: 0.9938, step time: 0.3374
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 15/225, train_loss: 0.9905, step time: 0.3403
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 16/225, train_loss: 0.9954, step time: 0.3407
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 17/225, train_loss: 0.9899, step time: 0.3385
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 18/225, train_loss: 0.9966, step time: 0.3382
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 19/225, train_loss: 0.9925, step time: 0.3364
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 20/225, train_loss: 0.9957, step time: 0.3376
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 21/225, train_loss: 0.9956, step time: 0.3353
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 22/225, train_loss: 0.9955, step time: 0.3408
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 23/225, train_loss: 0.9965, step time: 0.3344
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 24/225, train_loss: 0.9965, step time: 0.3355
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 25/225, train_loss: 0.9927, step time: 0.3456
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 26/225, train_loss: 0.9909, step time: 0.3385
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 27/225, train_loss: 0.9961, step time: 0.3365
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 28/225, train_loss: 0.9921, step time: 0.3347
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 29/225, train_loss: 0.9909, step time: 0.3360
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 30/225, train_loss: 0.9937, step time: 0.3436
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 31/225, train_loss: 0.9888, step time: 0.3385
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 32/225, train_loss: 0.9850, step time: 0.3393
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 33/225, train_loss: 0.9968, step time: 0.3394
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 34/225, train_loss: 0.9919, step time: 0.3402
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 35/225, train_loss: 0.9911, step time: 0.3352
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 36/225, train_loss: 0.9722, step time: 0.3357
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 37/225, train_loss: 0.9871, step time: 0.3397
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 38/225, train_loss: 0.9968, step time: 0.3372
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 39/225, train_loss: 0.9900, step time: 0.3321
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 40/225, train_loss: 0.9933, step time: 0.3322
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 41/225, train_loss: 0.9902, step time: 0.3348
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 42/225, train_loss: 0.9889, step time: 0.3372
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 43/225, train_loss: 0.9946, step time: 0.3392
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 44/225, train_loss: 0.9913, step time: 0.3376
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 45/225, train_loss: 0.9845, step time: 0.3387
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 46/225, train_loss: 0.9926, step time: 0.3361
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 47/225, train_loss: 0.9980, step time: 0.3317
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
#
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 25/225, train_loss: 0.8895, step time: 0.3374
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 26/225, train_loss: 0.8958, step time: 0.3393
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 27/225, train_loss: 0.7647, step time: 0.3402
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 28/225, train_loss: 0.8008, step time: 0.3388
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 29/225, train_loss: 0.7727, step time: 0.3354
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 30/225, train_loss: 0.7658, step time: 0.3391
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 31/225, train_loss: 0.8450, step time: 0.3366
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 32/225, train_loss: 0.8628, step time: 0.3372
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 33/225, train_loss: 0.7167, step time: 0.3365
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 34/225, train_loss: 0.8224, step time: 0.3422
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 35/225, train_loss: 0.9362, step time: 0.3414
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 36/225, train_loss: 0.8254, step time: 0.3404
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 37/225, train_loss: 0.7967, step time: 0.3438
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 38/225, train_loss: 0.8609, step time: 0.4119
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 39/225, train_loss: 0.7831, step time: 0.3401
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 40/225, train_loss: 0.7966, step time: 0.3385
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 41/225, train_loss: 0.6938, step time: 0.3361
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 42/225, train_loss: 0.9197, step time: 0.4246
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 43/225, train_loss: 0.7855, step time: 0.3347
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 44/225, train_loss: 0.8010, step time: 0.3383
# Input size: torch.Size([1, 1, 224, 224, 144]), label size: torch.Size([1, 2, 224, 224, 144])
# 45/225, train_loss: 0.7802, step time: 0.3345
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 15
#      13 epoch_loss = 0
#      14 step = 0
# ---> 15 for batch_data in train_loader:
#      16     step_start = time.time()
#      17     step += 1
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:1328, in _MultiProcessingDataLoaderIter._next_data(self)
#    1325     return self._process_data(data)
#    1327 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1328 idx, data = self._get_data()
#    1329 self._tasks_outstanding -= 1
#    1330 if self._dataset_kind == _DatasetKind.Iterable:
#    1331     # Check for _IterableDatasetStopIteration
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:1294, in _MultiProcessingDataLoaderIter._get_data(self)
#    1290     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1291     # need to call `.task_done()` because we don't use `.join()`.
#    1292 else:
#    1293     while True:
# -> 1294         success, data = self._try_get_data()
#    1295         if success:
#    1296             return data
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:1132, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1119 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1120     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1121     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1129     # Returns a 2-tuple:
#    1130     #   (bool: whether successfully get data, any: data if successful else None)
#    1131     try:
# -> 1132         data = self._data_queue.get(timeout=timeout)
#    1133         return (True, data)
#    1134     except Exception as e:
#    1135         # At timeout and error, we manually check whether any worker has
#    1136         # failed. Note that this is the only mechanism for Windows to detect
#    1137         # worker failures.
#
# File /usr/lib/python3.8/multiprocessing/queues.py:107, in Queue.get(self, block, timeout)
#     105 if block:
#     106     timeout = deadline - time.monotonic()
# --> 107     if not self._poll(timeout):
#     108         raise Empty
#     109 elif not self._poll():
#
# File /usr/lib/python3.8/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File /usr/lib/python3.8/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File /usr/lib/python3.8/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File /usr/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

epochs = range(1, max_epochs + 1)

plt.plot(epochs, metric_values, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Mean Dice Score')
plt.title('Epochs vs Mean Dice Score')
plt.grid(True)
plt.show()
