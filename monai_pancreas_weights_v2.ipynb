# %%
import os
import time
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import nibabel as nib
from sklearn.model_selection import train_test_split
from monai.config import print_config
from monai.data import DataLoader, Dataset, ArrayDataset, CacheDataset
from monai.data.utils import pad_list_data_collate, decollate_batch
from monai.handlers.utils import from_engine
from monai.inferers import sliding_window_inference
from monai.losses import DiceLoss, TverskyLoss,DiceCELoss
from monai.metrics import DiceMetric
from monai.networks.nets import SegResNet
from monai.transforms import (
    Activations, AsDiscrete, Compose, LoadImaged, EnsureChannelFirstd, EnsureTyped,
    Transform, AsDiscreted, CropForegroundd,RandGaussianNoised,RandScaleIntensityd,
    NormalizeIntensityd, ResizeD,  ToTensord, ScaleIntensityRanged, Orientationd,
     Spacingd, ToDeviced,RandGaussianNoised,RandShiftIntensityd
)
import glob
import math
from monai.utils import set_determinism

# %%
# Set the data directory path
data_dir = "/home/Task07_Pancreas/"

# Get the file paths of the training images and labels
train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))

# Create a list of dictionaries, each containing an image-label pair
data_dicts = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]

# Split the data into validation and training sets
val_files, train_files = data_dicts[:5], data_dicts[25:35]

# %%
class GettheDesiredLabels(Transform):
    def __call__(self, data):
        # Extract the label from the input data
        label = data["label"]

        # Keep only the second and third channels from the label
        single_label = label[1:3]

        # Replace the original label with the modified label
        data["label"] = single_label

        # Return the modified data
        return data

# %%
train_transforms = Compose([
    LoadImaged(keys=["image", "label"]),  # Load the image and label data from file
    EnsureChannelFirstd(keys=["image", "label"]),  # Ensure the channel dimension is the first dimension
    ToDeviced(keys=["image", "label"], device="cuda:2"),  # Move the data to the specified device (commented out)
    AsDiscreted(keys='label', to_onehot=3),  # Convert the label to one-hot encoding with 3 channels
    GettheDesiredLabels(),  # Extract the desired channels from the label
    ScaleIntensityRanged(
        keys=["image"],
        a_min=-57,
        a_max=164,
        b_min=0.0,
        b_max=1.0,
        clip=True,
    ),  # Rescale the intensity values of the image within the specified range
    CropForegroundd(keys=["image", "label"], source_key="image"),  # Crop the image and label to remove the background
    Orientationd(keys=["image", "label"], axcodes="RAS"),  # Adjust the image and label orientation to RAS
    Spacingd(keys=["image", "label"], pixdim=(1, 1, 1), mode=("bilinear", "nearest")),  # Adjust the spacing of the image and label
    ResizeD(keys=["image", "label"], spatial_size=[224, 224, 144], mode=("trilinear", "nearest")),  # Resize the image and label to the specified spatial size
    NormalizeIntensityd(keys=["image"]),  # Normalize intensity values of the image
    RandScaleIntensityd(keys=["image"], factors=0.1),  # Apply random scaling of intensity values to the image
    RandShiftIntensityd(keys=["image"], offsets=0.1),  # Apply random shifting of intensity values to the image
    RandGaussianNoised(keys=["image"], std=0.1),  # Add random Gaussian noise to the image
    ToTensord(keys=["image", "label"]),  # Convert the image and label to PyTorch tensors
])

val_transforms = Compose([
    LoadImaged(keys=["image", "label"]),  # Load the image and label data from file
    EnsureChannelFirstd(keys=["image", "label"]),  # Ensure the channel dimension is the first dimension
    AsDiscreted(keys='label', to_onehot=3),  # Convert the label to one-hot encoding with 3 channels
    GettheDesiredLabels(),  # Extract the desired channels from the label
    ScaleIntensityRanged(
        keys=["image"],
        a_min=-57,
        a_max=164,
        b_min=0.0,
        b_max=1.0,
        clip=True,
    ),  # Rescale the intensity values of the image within the specified range
    CropForegroundd(keys=["image", "label"], source_key="image"),  # Crop the image and label to remove the background
    Orientationd(keys=["image", "label"], axcodes="RAS"),  # Adjust the image and label orientation to RAS
    Spacingd(keys=["image", "label"], pixdim=(1, 1, 1), mode=("bilinear", "nearest")),  # Adjust the spacing of the image and label
    ResizeD(keys=["image", "label"], spatial_size=[224, 224, 144], mode=("trilinear", "nearest")),  # Resize the image and label to the specified spatial size
    ToTensord(keys=["image", "label"]),  # Convert the image and label to PyTorch tensors
])

# %%
train_dataset = CacheDataset(data=train_files, transform=train_transforms)  # Create a dataset for training with the training files and specified transformations
val_dataset = CacheDataset(data=val_files, transform=val_transforms)  # Create a dataset for validation with the validation files and specified transformations

# Create the data loaders
train_loader = DataLoader(train_dataset, batch_size=1, collate_fn=pad_list_data_collate)  # Create a data loader for training with the training dataset
val_loader = DataLoader(val_dataset, batch_size=1, collate_fn=pad_list_data_collate)  # Create a data loader for validation with the validation dataset
# Out:
# Loading dataset: 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# Loading dataset: 100%|██████████| 5/5 [00:14<00:00,  2.95s/it]

# %%
print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of validation samples: {len(val_dataset)}")
# Out:
# Number of training samples: 10
# Number of validation samples: 5

# %%
sample_index = 0  # Specify the index of the sample to check
sample = train_dataset[sample_index]  # Retrieve the sample at the specified index from the training dataset
binarized_label = sample['label']  # Access the binarized label data from the sample
unique_values = torch.unique(binarized_label)  # Find the unique values in the binarized label
count = len(unique_values)  # Count the number of unique values
print(f"Number of unique values: {count}")  # Print the count of unique values
# Out:
# Number of unique values: 2

# %%
# Get the first sample in the dataset
first_sample = train_dataset[0]


image_shape = first_sample['image'].shape
label_shape = first_sample['label'].shape

print(f"Image shape: {image_shape}")
print(f"Label shape: {label_shape}")
# Out:
# Image shape: torch.Size([1, 224, 224, 144])
# Label shape: torch.Size([2, 224, 224, 144])

# %%
# Create a colormap for the blue label
colors = [(0, 0, 1, i) for i in np.linspace(0, 1, 100)]
blue_cmap = mcolors.LinearSegmentedColormap.from_list('blue_alpha', colors)

# Create a colormap for the red label
colors = [(1, 0, 0, i) for i in np.linspace(0, 1, 100)]
red_cmap = mcolors.LinearSegmentedColormap.from_list('red_alpha', colors)

# Loop over samples in the dataset
for i in range(1, 3):
    val_data_example = train_dataset[i]

    # Select a slice to visualize (e.g., the middle slice)
    slice_idx = val_data_example['image'].shape[3] // 2  # Adjust to the depth dimension
    print(slice_idx)

    # Get image and labels
    image = val_data_example['image'][0, :, :, slice_idx].detach().cpu()
    label3 = val_data_example['label'][1, :, :, slice_idx].detach().cpu()
    label2 = val_data_example['label'][0, :, :, slice_idx].detach().cpu()

    # Create a figure
    plt.figure(figsize=(18, 6))

    # Plot the image
    plt.subplot(1, 2, 1)
    plt.title("image")
    plt.imshow(image, cmap='gray')

    # Overlay the labels on the image
    plt.subplot(1, 2, 2)
    plt.title("image + label")
    plt.imshow(image, cmap='gray')
    plt.imshow(label2, cmap=blue_cmap, alpha=0.5)  # Use alpha for transparency
    plt.imshow(label3, cmap=red_cmap, alpha=0.5)

    # Show the plot
    plt.show()
# Out:
# 72
# 72

# %%
frequency_class1 = 0  # Frequency of class 1
frequency_class2 = 0  # Frequency of class 2

# Iterate over the training dataset
for data in train_dataset:
    labels = data["label"]

    # Count the number of voxels or samples belonging to each class
    frequency_class1 += torch.sum(labels == 0).item()
    frequency_class2 += torch.sum(labels == 1).item()

# Print the frequencies of each class
print("Frequency of class 1:", frequency_class1)
print("Frequency of class 2:", frequency_class2)
# Out:
# Frequency of class 1: 144265162
# Frequency of class 2: 241718

# %%
weight_class1 = 1.0 / math.sqrt(frequency_class1)
weight_class2 = 1.0 / math.sqrt(frequency_class2)

# %%
# Define your UNet model as a function
def segresnet(in_channels, out_channels):
    """

    Args:
        in_channels (int): Number of input channels.
        out_channels (int): Number of output channels.

    Returns:
        SegResNet: UNet model based on the SegResNet architecture.
    """

    # Create a SegResNet model with the specified parameters
    model = SegResNet(
        blocks_down=[1, 2, 2, 4],  # Number of residual blocks in each downsampling path
        blocks_up=[1, 1, 1],  # Number of residual blocks in each upsampling path
        init_filters=16,  # Number of filters in the first layer
        in_channels=in_channels,  # Number of input channels
        out_channels=out_channels,  # Number of output channels
        dropout_prob=0.2,  # Dropout probability
    )

    return model

# %%
device = torch.device('cuda:2')  # Specify the device to be used (e.g., 'cuda:0' for the first GPU)

device_ids = [2]  # Specify the GPU device IDs to be used

# Print the number of GPUs being used
num_gpus = len(device_ids)
print("Using", num_gpus, "GPUs!")
# Out:
# Using 1 GPUs!

# %%
in_channels = 1  # Number of input channels
out_channels = 2  # Number of output channels
model = segresnet(in_channels, out_channels)  
model = model.to(device)  # Move the model to the specified device (GPU)
if torch.cuda.device_count() > 1:
    print("Using", num_gpus, "GPUs!")
    model = nn.DataParallel(model, device_ids=device_ids)
# Out:
# Using 1 GPUs!

# %%
class HandleOverlap(Transform):
    def __call__(self, pred):
        # Find the overlapping pixels (those belong to both classes)
        overlap = (pred[0] > 0.5) & (pred[1] > 0.5)

        # Assign the overlapping pixels to the class with higher prediction probability
        class_0_overlap = pred[0] > pred[1]
        class_1_overlap = pred[1] >= pred[0]

        pred[0][overlap & class_0_overlap] = 1
        pred[1][overlap & class_1_overlap] = 1

        pred[0][overlap & class_1_overlap] = 0
        pred[1][overlap & class_0_overlap] = 0

        # Return the modified prediction
        return pred

# %%
val_interval = 1
VAL_AMP = True
max_epochs=100
# loss_function = DiceLoss(class_weights=[weight_class1, weight_class2],smooth_nr=0, smooth_dr=1e-5, squared_pred=True, to_onehot_y=False, sigmoid=True)

# loss_function = TverskyLoss(
#     to_onehot_y=False,
#     sigmoid=True,
#     softmax=False,
#     alpha=0.5,
#     beta=0.5,
#     reduction="mean",
#     smooth_nr=0,
#     smooth_dr=1e-05,
#     batch=False
# )
pancreas_weight=0.35
tumor_weight=1.5
ce_weights = torch.tensor([pancreas_weight, tumor_weight], device=device)
loss_function = DiceCELoss(ce_weight=ce_weights, smooth_nr=0, smooth_dr=1e-5, squared_pred=True, to_onehot_y=False, sigmoid=True)

optimizer = torch.optim.Adam(model.parameters(), 1e-4, weight_decay=1e-5)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

dice_metric = DiceMetric( reduction="mean")
dice_metric_batch = DiceMetric( reduction="mean_batch")


post_trans = Compose([
    Activations(sigmoid=True), 
    HandleOverlap(),  # handle overlap before converting to discrete values
    AsDiscrete(threshold=0.5)
])

# %%
def inference(input):
    def _compute(input):
        return sliding_window_inference(
            inputs=input,
            roi_size=(224, 224, 144),
            sw_batch_size=1,
            predictor=model,
            overlap=0.5,
        )

    if VAL_AMP:
        with torch.cuda.amp.autocast():
            return _compute(input)
    else:
        return _compute(input)


scaler = torch.cuda.amp.GradScaler()
torch.backends.cudnn.benchmark = True

# %%
best_metric = -1  # Initialize the best metric value
best_metric_epoch = -1  # Initialize the epoch corresponding to the best metric
best_metrics_epochs_and_time = [[], [], []]  # List to store the best metric, epoch, and time
epoch_loss_values = []  # List to store the loss value for each epoch
metric_values = []  # List to store the metric value for each epoch
metric_values_class1 = []  # List to store the metric value for class 1
metric_values_class2 = []  # List to store the metric value for class 2
model_dir = "/home/model_codes/"  # Directory to save the best metric model


total_start = time.time()  # Start time for total training

# Iterate over each epoch
for epoch in range(max_epochs):
    epoch_start = time.time()  # Start time for the current epoch

    model.train()  # Set the model in training mode
    epoch_loss = 0  # Initialize the epoch loss
    step = 0  # Initialize the step count

    # Iterate over each batch in the training loader
    for batch_data in train_loader:
        step_start = time.time()  # Start time for the current step
        step += 1

        # Move inputs and labels to the specified device (GPU)
        inputs, labels = batch_data["image"].to(device), batch_data["label"].to(device)

        optimizer.zero_grad()  # Clear the gradients
        with torch.cuda.amp.autocast():
            outputs = model(inputs)  # Forward pass
            loss = loss_function(outputs, labels)  # Compute the loss


        scaler.scale(loss).backward()  # Backward pass with gradient scaling
        scaler.step(optimizer)  # Update the model parameters
        scaler.update()  # Update the gradient scaler
        epoch_loss += loss.item()  # Accumulate the epoch loss

    lr_scheduler.step()  # Update the learning rate scheduler
    epoch_loss /= step  # Compute the average epoch loss
    epoch_loss_values.append(epoch_loss)  # Store the epoch loss
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    # Perform validation at specified intervals
    if (epoch + 1) % val_interval == 0:
        model.eval()  # Set the model in evaluation mode
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                val_outputs = inference(val_inputs)  # Perform inference on validation data
                val_outputs = [post_trans(i) for i in decollate_batch(val_outputs)]
                # val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                dice_metric(y_pred=val_outputs, y=val_labels)  # Compute the dice metric
                dice_metric_batch(y_pred=val_outputs, y=val_labels)

            metric = dice_metric.aggregate().item()  # Compute the aggregate metric value
            metric_values.append(metric)  # Store the metric value
            metric_batch = dice_metric_batch.aggregate()
            metric_class1 = metric_batch[0].item()  # Compute the metric value for class 1
            metric_values_class1.append(metric_class1)  # Store the metric value for class 1
            metric_class2 = metric_batch[1].item()  # Compute the metric value for class 2
            metric_values_class2.append(metric_class2)  # Store the metric value for class 2
            
            dice_metric.reset()  # Reset the dice metric
            dice_metric_batch.reset()

            # Check if the current metric is better than the best metric
            if metric > best_metric:
                best_metric = metric  # Update the best metric value
                best_metric_epoch = epoch + 1  # Update the epoch corresponding to the best metric
                best_metrics_epochs_and_time[0].append(best_metric)  # Store the best metric
                best_metrics_epochs_and_time[1].append(best_metric_epoch)  # Store the corresponding epoch
                best_metrics_epochs_and_time[2].append(time.time() - total_start)  # Store the total time
                torch.save(model, os.path.join(model_dir, "best_metric_model_diceceloss.pth"))  # Save the best model
                print("Saved new best metric model")

            # Print the current and best metric values
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
               f" class1: {metric_class1:.4f} class2: {metric_class2:.4f}"
                f"\nbest mean dice: {best_metric:.4f}"
                f" at epoch: {best_metric_epoch}"
            )

    print(f"time consuming of epoch {epoch + 1} is: {(time.time() - epoch_start):.4f}")

total_time = time.time() - total_start  # Compute the total training time
# Out:
# epoch 1 average loss: 0.9782
# Saved new best metric model
# current epoch: 1 current mean dice: 0.1652 class1: 0.3149 class2: 0.0154
# best mean dice: 0.1652 at epoch: 1
# time consuming of epoch 1 is: 89.1841
# epoch 2 average loss: 0.9576
# Saved new best metric model
# current epoch: 2 current mean dice: 0.1937 class1: 0.3511 class2: 0.0364
# best mean dice: 0.1937 at epoch: 2
# time consuming of epoch 2 is: 88.9052
# epoch 3 average loss: 0.9249
# Saved new best metric model
# current epoch: 3 current mean dice: 0.2735 class1: 0.4829 class2: 0.0640
# best mean dice: 0.2735 at epoch: 3
# time consuming of epoch 3 is: 88.1183
# epoch 4 average loss: 0.8634
# Saved new best metric model
# current epoch: 4 current mean dice: 0.3682 class1: 0.6231 class2: 0.1133
# best mean dice: 0.3682 at epoch: 4
# time consuming of epoch 4 is: 86.9835
# epoch 5 average loss: 0.7859
# Saved new best metric model
# current epoch: 5 current mean dice: 0.3713 class1: 0.5983 class2: 0.1443
# best mean dice: 0.3713 at epoch: 5
# time consuming of epoch 5 is: 84.6398
# epoch 6 average loss: 0.7151
# Saved new best metric model
# current epoch: 6 current mean dice: 0.3865 class1: 0.6099 class2: 0.1630
# best mean dice: 0.3865 at epoch: 6
# time consuming of epoch 6 is: 86.7975
# epoch 7 average loss: 0.6704
# Saved new best metric model
# current epoch: 7 current mean dice: 0.3991 class1: 0.6272 class2: 0.1710
# best mean dice: 0.3991 at epoch: 7
# time consuming of epoch 7 is: 85.9820
# epoch 8 average loss: 0.6394
# current epoch: 8 current mean dice: 0.3700 class1: 0.5560 class2: 0.1840
# best mean dice: 0.3991 at epoch: 7
# time consuming of epoch 8 is: 85.9805
# epoch 9 average loss: 0.6136
# current epoch: 9 current mean dice: 0.3942 class1: 0.5779 class2: 0.2106
# best mean dice: 0.3991 at epoch: 7
# time consuming of epoch 9 is: 86.0925
# epoch 10 average loss: 0.5954
# Saved new best metric model
# current epoch: 10 current mean dice: 0.4072 class1: 0.5644 class2: 0.2501
# best mean dice: 0.4072 at epoch: 10
# time consuming of epoch 10 is: 86.9274
# epoch 11 average loss: 0.5726
# Saved new best metric model
# current epoch: 11 current mean dice: 0.4283 class1: 0.6048 class2: 0.2518
# best mean dice: 0.4283 at epoch: 11
# time consuming of epoch 11 is: 87.3744
# epoch 12 average loss: 0.5527
# Saved new best metric model
# current epoch: 12 current mean dice: 0.4377 class1: 0.6026 class2: 0.2727
# best mean dice: 0.4377 at epoch: 12
# time consuming of epoch 12 is: 86.8652
# epoch 13 average loss: 0.5263
# Saved new best metric model
# current epoch: 13 current mean dice: 0.4416 class1: 0.5516 class2: 0.3315
# best mean dice: 0.4416 at epoch: 13
# time consuming of epoch 13 is: 86.8790
# epoch 14 average loss: 0.4870
# Saved new best metric model
# current epoch: 14 current mean dice: 0.4687 class1: 0.6136 class2: 0.3237
# best mean dice: 0.4687 at epoch: 14
# time consuming of epoch 14 is: 86.7842
# epoch 15 average loss: 0.4553
# current epoch: 15 current mean dice: 0.4672 class1: 0.5802 class2: 0.3543
# best mean dice: 0.4687 at epoch: 14
# time consuming of epoch 15 is: 86.7172
# epoch 16 average loss: 0.4234
# Saved new best metric model
# current epoch: 16 current mean dice: 0.4975 class1: 0.6500 class2: 0.3451
# best mean dice: 0.4975 at epoch: 16
# time consuming of epoch 16 is: 85.6197
# epoch 17 average loss: 0.3893
# current epoch: 17 current mean dice: 0.4895 class1: 0.6063 class2: 0.3727
# best mean dice: 0.4975 at epoch: 16
# time consuming of epoch 17 is: 86.6803
# epoch 18 average loss: 0.3620
# Saved new best metric model
# current epoch: 18 current mean dice: 0.5040 class1: 0.6506 class2: 0.3574
# best mean dice: 0.5040 at epoch: 18
# time consuming of epoch 18 is: 86.4650
# epoch 19 average loss: 0.3393
# current epoch: 19 current mean dice: 0.4859 class1: 0.6330 class2: 0.3388
# best mean dice: 0.5040 at epoch: 18
# time consuming of epoch 19 is: 85.7111
# epoch 20 average loss: 0.3244
# current epoch: 20 current mean dice: 0.4496 class1: 0.6305 class2: 0.2687
# best mean dice: 0.5040 at epoch: 18
# time consuming of epoch 20 is: 85.2829
# epoch 21 average loss: 0.3139
# current epoch: 21 current mean dice: 0.4318 class1: 0.6153 class2: 0.2484
# best mean dice: 0.5040 at epoch: 18
# time consuming of epoch 21 is: 86.2486
# epoch 22 average loss: 0.2935
# current epoch: 22 current mean dice: 0.4764 class1: 0.6445 class2: 0.3084
# best mean dice: 0.5040 at epoch: 18
# time consuming of epoch 22 is: 85.7291
# epoch 23 average loss: 0.2811
# Saved new best metric model
# current epoch: 23 current mean dice: 0.5048 class1: 0.6659 class2: 0.3438
# best mean dice: 0.5048 at epoch: 23
# time consuming of epoch 23 is: 86.0133
# epoch 24 average loss: 0.2709
# Saved new best metric model
# current epoch: 24 current mean dice: 0.5154 class1: 0.6677 class2: 0.3631
# best mean dice: 0.5154 at epoch: 24
# time consuming of epoch 24 is: 87.1960
# epoch 25 average loss: 0.2660
# Saved new best metric model
# current epoch: 25 current mean dice: 0.5209 class1: 0.6665 class2: 0.3753
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 25 is: 87.2788
# epoch 26 average loss: 0.2625
# current epoch: 26 current mean dice: 0.5140 class1: 0.6601 class2: 0.3678
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 26 is: 85.6879
# epoch 27 average loss: 0.2561
# current epoch: 27 current mean dice: 0.4976 class1: 0.6534 class2: 0.3418
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 27 is: 85.5943
# epoch 28 average loss: 0.2525
# current epoch: 28 current mean dice: 0.4845 class1: 0.6506 class2: 0.3184
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 28 is: 87.6573
# epoch 29 average loss: 0.2496
# current epoch: 29 current mean dice: 0.4740 class1: 0.6539 class2: 0.2941
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 29 is: 87.0196
# epoch 30 average loss: 0.2471
# current epoch: 30 current mean dice: 0.4808 class1: 0.6571 class2: 0.3044
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 30 is: 85.7108
# epoch 31 average loss: 0.2453
# current epoch: 31 current mean dice: 0.4808 class1: 0.6571 class2: 0.3044
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 31 is: 85.4975
# epoch 32 average loss: 0.2460
# current epoch: 32 current mean dice: 0.4827 class1: 0.6596 class2: 0.3059
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 32 is: 86.5907
# epoch 33 average loss: 0.2457
# current epoch: 33 current mean dice: 0.4790 class1: 0.6559 class2: 0.3021
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 33 is: 87.5064
# epoch 34 average loss: 0.2453
# current epoch: 34 current mean dice: 0.4819 class1: 0.6513 class2: 0.3125
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 34 is: 84.0836
# epoch 35 average loss: 0.2420
# current epoch: 35 current mean dice: 0.4886 class1: 0.6533 class2: 0.3240
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 35 is: 86.2135
# epoch 36 average loss: 0.2383
# current epoch: 36 current mean dice: 0.4948 class1: 0.6552 class2: 0.3345
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 36 is: 84.2252
# epoch 37 average loss: 0.2348
# current epoch: 37 current mean dice: 0.4883 class1: 0.6585 class2: 0.3182
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 37 is: 87.5390
# epoch 38 average loss: 0.2364
# current epoch: 38 current mean dice: 0.4889 class1: 0.6711 class2: 0.3067
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 38 is: 85.8321
# epoch 39 average loss: 0.2366
# current epoch: 39 current mean dice: 0.4634 class1: 0.6473 class2: 0.2794
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 39 is: 86.5560
# epoch 40 average loss: 0.2325
# current epoch: 40 current mean dice: 0.5082 class1: 0.6683 class2: 0.3481
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 40 is: 85.0491
# epoch 41 average loss: 0.2340
# current epoch: 41 current mean dice: 0.5077 class1: 0.6675 class2: 0.3479
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 41 is: 84.5201
# epoch 42 average loss: 0.2335
# current epoch: 42 current mean dice: 0.4776 class1: 0.6383 class2: 0.3169
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 42 is: 85.3971
# epoch 43 average loss: 0.2500
# current epoch: 43 current mean dice: 0.4317 class1: 0.6554 class2: 0.2080
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 43 is: 86.0040
# epoch 44 average loss: 0.2344
# current epoch: 44 current mean dice: 0.4493 class1: 0.6452 class2: 0.2534
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 44 is: 86.7071
# epoch 45 average loss: 0.2305
# current epoch: 45 current mean dice: 0.4111 class1: 0.6322 class2: 0.1899
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 45 is: 86.2838
# epoch 46 average loss: 0.2330
# current epoch: 46 current mean dice: 0.4433 class1: 0.6342 class2: 0.2524
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 46 is: 84.4965
# epoch 47 average loss: 0.2307
# current epoch: 47 current mean dice: 0.4690 class1: 0.6265 class2: 0.3116
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 47 is: 86.4394
# epoch 48 average loss: 0.2309
# current epoch: 48 current mean dice: 0.4569 class1: 0.6454 class2: 0.2685
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 48 is: 84.7981
# epoch 49 average loss: 0.2193
# current epoch: 49 current mean dice: 0.4220 class1: 0.6591 class2: 0.1848
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 49 is: 86.9338
# epoch 50 average loss: 0.2289
# current epoch: 50 current mean dice: 0.4672 class1: 0.6561 class2: 0.2783
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 50 is: 87.2507
# epoch 51 average loss: 0.2241
# current epoch: 51 current mean dice: 0.4145 class1: 0.6505 class2: 0.1785
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 51 is: 85.8290
# epoch 52 average loss: 0.2037
# current epoch: 52 current mean dice: 0.4609 class1: 0.6301 class2: 0.2916
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 52 is: 86.2627
# epoch 53 average loss: 0.2061
# current epoch: 53 current mean dice: 0.4735 class1: 0.6461 class2: 0.3008
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 53 is: 86.2024
# epoch 54 average loss: 0.2128
# current epoch: 54 current mean dice: 0.4493 class1: 0.6568 class2: 0.2418
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 54 is: 85.3778
# epoch 55 average loss: 0.2235
# current epoch: 55 current mean dice: 0.4680 class1: 0.6826 class2: 0.2534
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 55 is: 86.6658
# epoch 56 average loss: 0.2000
# current epoch: 56 current mean dice: 0.4384 class1: 0.6652 class2: 0.2117
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 56 is: 85.4311
# epoch 57 average loss: 0.2097
# current epoch: 57 current mean dice: 0.4734 class1: 0.6335 class2: 0.3133
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 57 is: 86.9076
# epoch 58 average loss: 0.2035
# current epoch: 58 current mean dice: 0.4697 class1: 0.6342 class2: 0.3051
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 58 is: 87.9775
# epoch 59 average loss: 0.2036
# current epoch: 59 current mean dice: 0.4711 class1: 0.6801 class2: 0.2620
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 59 is: 86.9060
# epoch 60 average loss: 0.1856
# current epoch: 60 current mean dice: 0.4420 class1: 0.6286 class2: 0.2553
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 60 is: 87.6453
# epoch 61 average loss: 0.2035
# current epoch: 61 current mean dice: 0.4187 class1: 0.6287 class2: 0.2086
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 61 is: 86.2605
# epoch 62 average loss: 0.1981
# current epoch: 62 current mean dice: 0.4254 class1: 0.6336 class2: 0.2172
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 62 is: 87.1883
# epoch 63 average loss: 0.1820
# current epoch: 63 current mean dice: 0.5053 class1: 0.6900 class2: 0.3205
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 63 is: 86.2575
# epoch 64 average loss: 0.1813
# current epoch: 64 current mean dice: 0.4990 class1: 0.6645 class2: 0.3336
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 64 is: 86.3392
# epoch 65 average loss: 0.1712
# current epoch: 65 current mean dice: 0.4583 class1: 0.6532 class2: 0.2633
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 65 is: 86.3172
# epoch 66 average loss: 0.1777
# current epoch: 66 current mean dice: 0.4180 class1: 0.6273 class2: 0.2086
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 66 is: 83.9515
# epoch 67 average loss: 0.1785
# current epoch: 67 current mean dice: 0.3843 class1: 0.6654 class2: 0.1033
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 67 is: 86.4011
# epoch 68 average loss: 0.1759
# current epoch: 68 current mean dice: 0.4786 class1: 0.6531 class2: 0.3041
# best mean dice: 0.5209 at epoch: 25
# time consuming of epoch 68 is: 87.0810
# epoch 69 average loss: 0.1626
# Saved new best metric model
# current epoch: 69 current mean dice: 0.5321 class1: 0.6964 class2: 0.3678
# best mean dice: 0.5321 at epoch: 69
# time consuming of epoch 69 is: 86.0583
# epoch 70 average loss: 0.1578
# current epoch: 70 current mean dice: 0.4888 class1: 0.6570 class2: 0.3206
# best mean dice: 0.5321 at epoch: 69
# time consuming of epoch 70 is: 86.0676
# epoch 71 average loss: 0.1525
# current epoch: 71 current mean dice: 0.4939 class1: 0.6720 class2: 0.3157
# best mean dice: 0.5321 at epoch: 69
# time consuming of epoch 71 is: 85.1768
# epoch 72 average loss: 0.1502
# current epoch: 72 current mean dice: 0.4437 class1: 0.6898 class2: 0.1977
# best mean dice: 0.5321 at epoch: 69
# time consuming of epoch 72 is: 85.7149
# epoch 73 average loss: 0.1444
# current epoch: 73 current mean dice: 0.4937 class1: 0.6725 class2: 0.3150
# best mean dice: 0.5321 at epoch: 69
# time consuming of epoch 73 is: 86.7235
# epoch 74 average loss: 0.1445
# current epoch: 74 current mean dice: 0.5161 class1: 0.6781 class2: 0.3542
# best mean dice: 0.5321 at epoch: 69
# time consuming of epoch 74 is: 85.5290
# epoch 75 average loss: 0.1417
# Saved new best metric model
# current epoch: 75 current mean dice: 0.5349 class1: 0.6631 class2: 0.4067
# best mean dice: 0.5349 at epoch: 75
# time consuming of epoch 75 is: 84.4515
# epoch 76 average loss: 0.1365
# current epoch: 76 current mean dice: 0.4610 class1: 0.6395 class2: 0.2824
# best mean dice: 0.5349 at epoch: 75
# time consuming of epoch 76 is: 85.6698
# epoch 77 average loss: 0.1334
# current epoch: 77 current mean dice: 0.4638 class1: 0.6518 class2: 0.2759
# best mean dice: 0.5349 at epoch: 75
# time consuming of epoch 77 is: 86.5920
# epoch 78 average loss: 0.1308
# current epoch: 78 current mean dice: 0.4657 class1: 0.6590 class2: 0.2724
# best mean dice: 0.5349 at epoch: 75
# time consuming of epoch 78 is: 86.8667
# epoch 79 average loss: 0.1282
# current epoch: 79 current mean dice: 0.4329 class1: 0.6388 class2: 0.2270
# best mean dice: 0.5349 at epoch: 75
# time consuming of epoch 79 is: 85.8053
# epoch 80 average loss: 0.1252
# current epoch: 80 current mean dice: 0.4056 class1: 0.6100 class2: 0.2012
# best mean dice: 0.5349 at epoch: 75
# time consuming of epoch 80 is: 87.0184
# epoch 81 average loss: 0.1249
# current epoch: 81 current mean dice: 0.4156 class1: 0.6511 class2: 0.1800
# best mean dice: 0.5349 at epoch: 75
# time consuming of epoch 81 is: 84.9350
# epoch 82 average loss: 0.1241
# current epoch: 82 current mean dice: 0.4434 class1: 0.6830 class2: 0.2038
# best mean dice: 0.5349 at epoch: 75
# time consuming of epoch 82 is: 86.3846

# %%
# Out:
# Saved new best metric model

# %% [markdown]
# 8000 pixels - bg - all classified correctly
# 1500 pixels - class 1 -  all classified correctly
# 500 pixels - class 2 -  all classified incorrectly
#
# separated channel
# dice score - 2TP/(2TP+FN+FP)
# 1) bg - 2*8000/(2*8000+0+0)=1
#     dice loss = 1-1=0
# 2) class 1 - dice loss = 0
# 3) class 2 - all incorrect = dice loss = 1
#
# avg loss = (0+0+1)/3= 0.333
#
# same channel
#
# dice score = 2*9500/(2*9500+500+0)= 0.9744 = 1- 0.9744 = loss - 0.0256

# %%
import matplotlib.pyplot as plt

# Plot epochs vs train loss
plt.figure(figsize=(10, 6))
plt.plot(range(1, max_epochs + 1), epoch_loss_values, label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Epochs vs. Train Loss')
plt.legend()
plt.show()

# Plot epochs vs mean dice score
plt.figure(figsize=(10, 6))
plt.plot(range(val_interval, max_epochs + 1, val_interval), metric_values, label='Mean Dice Score')
plt.xlabel('Epoch')
plt.ylabel('Mean Dice Score')
plt.title('Epochs vs. Mean Dice Score')
plt.legend()
plt.show()

# Plot epochs vs class 1, 2, and 3 dice scores
plt.figure(figsize=(10, 6))
plt.plot(range(val_interval, max_epochs + 1, val_interval), metric_values_class1, label='Pancreas')
plt.plot(range(val_interval, max_epochs + 1, val_interval), metric_values_class2, label='Tumor')

plt.xlabel('Epoch')
plt.ylabel('Dice Score')
plt.title('Epochs vs. Dice Score (Pancreas and Tumor)')
plt.legend()
plt.show()

# %%
model.eval()  # Set the model in evaluation mode
with torch.no_grad():
    for val_data in val_loader:
        val_inputs, val_labels = (
            val_data["image"].to(device),
            val_data["label"].to(device),
        )
        val_outputs = inference(val_inputs)  # Perform inference on validation data
        val_outputs = [post_trans(i) for i in decollate_batch(val_outputs)]
        
        # Convert the predictions to binary labels
        pred_labels_class1 = torch.argmax(val_outputs[0], dim=1)  # Predicted labels for class 1
        pred_labels_class2 = torch.argmax(val_outputs[1], dim=1)  # Predicted labels for class 2
        
        # Calculate the overlapping pixels between the predicted labels for class 1 and class 2
        overlapping_pixels = torch.sum(pred_labels_class1 & pred_labels_class2).item()
        total_pixels = pred_labels_class1.numel()  # Total number of pixels
        
        overlap_percentage = (overlapping_pixels / total_pixels) * 100
        
        print(f"Overlap percentage between class 1 and class 2: {overlap_percentage:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 13
#      11 # Convert the predictions to binary labels
#      12 pred_labels_class1 = torch.argmax(val_outputs[0], dim=1)  # Predicted labels for class 1
# ---> 13 pred_labels_class2 = torch.argmax(val_outputs[1], dim=1)  # Predicted labels for class 2
#      15 # Calculate the overlapping pixels between the predicted labels for class 1 and class 2
#      16 overlapping_pixels = torch.sum(pred_labels_class1 & pred_labels_class2).item()
#
# IndexError: list index out of range

# %%
model_dir = "/home/model_codes/"
model=(torch.load(
    os.path.join(model_dir, "best_metric_model_diceceloss.pth")))

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Set the model to evaluation mode
model.eval()

# Create a colormap for the blue label
colors = [(0, 0, 1, i) for i in np.linspace(0, 1, 100)]
blue_cmap = mcolors.LinearSegmentedColormap.from_list('blue_alpha', colors)

# Create a colormap for the red label
colors = [(1, 0, 0, i) for i in np.linspace(0, 1, 100)]
red_cmap = mcolors.LinearSegmentedColormap.from_list('red_alpha', colors)

# Create empty lists to store the original image, model prediction, and actual labels
original_images = []
model_predictions = []
actual_labels = []

# Iterate over the validation dataset
with torch.no_grad():
    for val_data in val_loader:
        val_inputs, val_labels = (
            val_data["image"].to(device),
            val_data["label"].to(device),
        )
        
        # Forward pass through the model to obtain the predictions
        val_outputs = model(val_inputs)
        
        # Convert the predicted outputs and actual labels to numpy arrays
        val_outputs = val_outputs.cpu().numpy()
        val_labels = val_labels.cpu().numpy()
        
        # Append the original image, model prediction, and actual labels to the respective lists
        original_images.append(val_inputs.cpu().numpy())
        model_predictions.append(val_outputs)
        actual_labels.append(val_labels)

# Convert the lists to numpy arrays
original_images = np.concatenate(original_images, axis=0)
model_predictions = np.concatenate(model_predictions, axis=0)
actual_labels = np.concatenate(actual_labels, axis=0)

# Apply threshold to model predictions
threshold = 0.5
model_predictions = np.where(model_predictions >= threshold, 1, 0)

# Iterate over the last 10 images in the validation set and visualize the original image, model prediction, and actual labels
for i in range(len(original_images)):
    plt.figure(figsize=(12, 4))
    
    # Plot the original image
    plt.subplot(1, 3, 1)
    plt.imshow(original_images[i, 0, :, :, 72], cmap='gray')
    plt.title("Original Image")
    plt.axis('off')
    
    # Plot the image with actual labels (pancreas in blue, tumor in red)
    plt.subplot(1, 3, 2)
    plt.imshow(original_images[i, 0, :, :, 72], cmap='gray')
    plt.imshow(actual_labels[i, 0, :, :, 72], cmap=blue_cmap, alpha=0.5)
    plt.imshow(actual_labels[i, 1, :, :, 72], cmap=red_cmap, alpha=0.5)
    plt.title("Actual Labels - Pancreas (Blue) and Tumor (Red)")
    plt.axis('off')
    
    # Plot the image with predicted labels (pancreas in blue, tumor in red)
    plt.subplot(1, 3, 3)
    plt.imshow(original_images[i, 0, :, :, 72], cmap='gray')
    plt.imshow(model_predictions[i, 0, :, :, 72], cmap=blue_cmap, alpha=0.5)
    plt.imshow(model_predictions[i, 1, :, :, 72], cmap=red_cmap, alpha=0.5)
    plt.title("Predicted Labels - Pancreas (Blue) and Tumor (Red)")
    plt.axis('off')
    
    plt.show()

# %%
d = 68
c1 = model_predictions[0, 0, :, :, d]
c2 = model_predictions[0, 1, :, :, d]

# %%
((c1 + c2) == 2).sum()
# Out:
# 3

# %%
c3 = model_predictions[2, 0, :, :, d]
c4 = model_predictions[2, 1, :, :, d]
((c3 + c4) == 2).sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# Iterate over the predicted labels
for i in range(model_predictions.shape[0]):
    label1 = model_predictions[i, 0, :, :, d]
    label2 = model_predictions[i, 1, :, :, d]
    
    # Calculate the overlap
    overlap = np.logical_and(label1, label2)

    # Count overlapping pixels
    num_overlapping_pixels = np.sum(overlap)
    print(f"Number of overlapping pixels: {num_overlapping_pixels}")

    if num_overlapping_pixels > 0:  # If there is any overlap
        # Create a figure and axes
        fig, ax = plt.subplots(1, 3, figsize=(15, 5))

        # Show the two labels and their overlap
        ax[0].imshow(label1, cmap='gray')
        ax[0].set_title("Label 1")

        ax[1].imshow(label2, cmap='gray')
        ax[1].set_title("Label 2")

        ax[2].imshow(overlap, cmap='gray')
        ax[2].set_title("Overlap")

        # Display the figure
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Iterate over the predicted labels
# ----> 4 for i in range(model_predictions.shape[0]):
#       5     label1 = model_predictions[i, 0, :, :, d]
#       6     label2 = model_predictions[i, 1, :, :, d]
#
# NameError: name 'model_predictions' is not defined
